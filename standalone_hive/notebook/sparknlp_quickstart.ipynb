# %%
import sparknlp
from sparknlp.pretrained import PretrainedPipeline

# %%
spark = sparknlp.start()
# Out:
# :: loading settings :: url = jar:file:/opt/spark/jars/ivy-2.5.1.jar!/org/apache/ivy/core/settings/ivysettings.xml
# Ivy Default Cache set to: /root/.ivy2/cache
# The jars for the packages stored in: /root/.ivy2/jars
# com.johnsnowlabs.nlp#spark-nlp_2.12 added as a dependency
# :: resolving dependencies :: org.apache.spark#spark-submit-parent-2959cbcc-95a2-4ea9-8215-ed3a12ce8d8c;1.0
# 	confs: [default]
# 	found com.johnsnowlabs.nlp#spark-nlp_2.12;6.1.2 in central
# 	found com.typesafe#config;1.4.2 in central
# 	found org.rocksdb#rocksdbjni;6.29.5 in central
# 	found com.amazonaws#aws-java-sdk-s3;1.12.500 in central
# 	found com.amazonaws#aws-java-sdk-kms;1.12.500 in central
# 	found com.amazonaws#aws-java-sdk-core;1.12.500 in central
# 	found commons-logging#commons-logging;1.1.3 in central
# 	found commons-codec#commons-codec;1.15 in central
# 	found org.apache.httpcomponents#httpclient;4.5.13 in central
# 	found org.apache.httpcomponents#httpcore;4.4.13 in central
# 	found software.amazon.ion#ion-java;1.0.2 in central
# 	found joda-time#joda-time;2.8.1 in central
# 	found com.amazonaws#jmespath-java;1.12.500 in central
# 	found com.github.universal-automata#liblevenshtein;3.0.0 in central
# 	found com.google.protobuf#protobuf-java-util;3.0.0-beta-3 in central
# 	found com.google.protobuf#protobuf-java;3.0.0-beta-3 in central
# 	found com.google.code.gson#gson;2.3 in central
# 	found it.unimi.dsi#fastutil;7.0.12 in central
# 	found org.projectlombok#lombok;1.16.8 in central
# 	found com.google.cloud#google-cloud-storage;2.20.1 in central
# 	found com.google.guava#guava;31.1-jre in central
# 	found com.google.guava#failureaccess;1.0.1 in central
# 	found com.google.guava#listenablefuture;9999.0-empty-to-avoid-conflict-with-guava in central
# 	found com.google.errorprone#error_prone_annotations;2.18.0 in central
# 	found com.google.j2objc#j2objc-annotations;1.3 in central
# 	found com.google.http-client#google-http-client;1.43.0 in central
# 	found io.opencensus#opencensus-contrib-http-util;0.31.1 in central
# 	found com.google.http-client#google-http-client-jackson2;1.43.0 in central
# 	found com.google.http-client#google-http-client-gson;1.43.0 in central
# 	found com.google.api-client#google-api-client;2.2.0 in central
# 	found com.google.oauth-client#google-oauth-client;1.34.1 in central
# 	found com.google.http-client#google-http-client-apache-v2;1.43.0 in central
# 	found com.google.apis#google-api-services-storage;v1-rev20220705-2.0.0 in central
# 	found com.google.code.gson#gson;2.10.1 in central
# 	found com.google.cloud#google-cloud-core;2.12.0 in central
# 	found io.grpc#grpc-context;1.53.0 in central
# 	found com.google.auto.value#auto-value-annotations;1.10.1 in central
# 	found com.google.auto.value#auto-value;1.10.1 in central
# 	found javax.annotation#javax.annotation-api;1.3.2 in central
# 	found com.google.cloud#google-cloud-core-http;2.12.0 in central
# 	found com.google.http-client#google-http-client-appengine;1.43.0 in central
# 	found com.google.api#gax-httpjson;0.108.2 in central
# 	found com.google.cloud#google-cloud-core-grpc;2.12.0 in central
# 	found io.grpc#grpc-alts;1.53.0 in central
# 	found io.grpc#grpc-grpclb;1.53.0 in central
# 	found org.conscrypt#conscrypt-openjdk-uber;2.5.2 in central
# 	found io.grpc#grpc-auth;1.53.0 in central
# 	found io.grpc#grpc-protobuf;1.53.0 in central
# 	found io.grpc#grpc-protobuf-lite;1.53.0 in central
# 	found io.grpc#grpc-core;1.53.0 in central
# 	found com.google.api#gax;2.23.2 in central
# 	found com.google.api#gax-grpc;2.23.2 in central
# 	found com.google.auth#google-auth-library-credentials;1.16.0 in central
# 	found com.google.auth#google-auth-library-oauth2-http;1.16.0 in central
# 	found com.google.api#api-common;2.6.2 in central
# 	found io.opencensus#opencensus-api;0.31.1 in central
# 	found com.google.api.grpc#proto-google-iam-v1;1.9.2 in central
# 	found com.google.protobuf#protobuf-java;3.21.12 in central
# 	found com.google.protobuf#protobuf-java-util;3.21.12 in central
# 	found com.google.api.grpc#proto-google-common-protos;2.14.2 in central
# 	found org.threeten#threetenbp;1.6.5 in central
# 	found com.google.api.grpc#proto-google-cloud-storage-v2;2.20.1-alpha in central
# 	found com.google.api.grpc#grpc-google-cloud-storage-v2;2.20.1-alpha in central
# 	found com.google.api.grpc#gapic-google-cloud-storage-v2;2.20.1-alpha in central
# 	found com.google.code.findbugs#jsr305;3.0.2 in central
# 	found io.grpc#grpc-api;1.53.0 in central
# 	found io.grpc#grpc-stub;1.53.0 in central
# 	found org.checkerframework#checker-qual;3.31.0 in central
# 	found io.perfmark#perfmark-api;0.26.0 in central
# 	found com.google.android#annotations;4.1.1.4 in central
# 	found org.codehaus.mojo#animal-sniffer-annotations;1.22 in central
# 	found io.opencensus#opencensus-proto;0.2.0 in central
# 	found io.grpc#grpc-services;1.53.0 in central
# 	found com.google.re2j#re2j;1.6 in central
# 	found io.grpc#grpc-netty-shaded;1.53.0 in central
# 	found io.grpc#grpc-googleapis;1.53.0 in central
# 	found io.grpc#grpc-xds;1.53.0 in central
# 	found com.navigamez#greex;1.0 in central
# 	found dk.brics.automaton#automaton;1.11-8 in central
# 	found org.jsoup#jsoup;1.18.2 in central
# 	found jakarta.mail#jakarta.mail-api;2.1.3 in central
# 	found jakarta.activation#jakarta.activation-api;2.1.3 in central
# 	found org.eclipse.angus#angus-mail;2.0.3 in central
# 	found org.eclipse.angus#angus-activation;2.0.2 in central
# 	found org.apache.poi#poi-ooxml;4.1.2 in central
# 	found org.apache.poi#poi;4.1.2 in central
# 	found org.apache.commons#commons-collections4;4.4 in central
# 	found org.apache.commons#commons-math3;3.6.1 in central
# 	found com.zaxxer#SparseBitSet;1.2 in central
# 	found org.apache.poi#poi-ooxml-schemas;4.1.2 in central
# 	found org.apache.xmlbeans#xmlbeans;3.1.0 in central
# 	found org.apache.commons#commons-compress;1.19 in central
# 	found com.github.virtuald#curvesapi;1.06 in central
# 	found org.apache.poi#poi-scratchpad;4.1.2 in central
# 	found org.apache.pdfbox#pdfbox;2.0.28 in central
# 	found org.apache.pdfbox#fontbox;2.0.28 in central
# 	found com.vladsch.flexmark#flexmark-all;0.61.34 in central
# 	found com.vladsch.flexmark#flexmark;0.61.34 in central
# 	found com.vladsch.flexmark#flexmark-util-ast;0.61.34 in central
# 	found com.vladsch.flexmark#flexmark-util-collection;0.61.34 in central
# 	found com.vladsch.flexmark#flexmark-util-misc;0.61.34 in central
# 	found org.jetbrains#annotations;15.0 in central
# 	found com.vladsch.flexmark#flexmark-util-data;0.61.34 in central
# 	found com.vladsch.flexmark#flexmark-util-sequence;0.61.34 in central
# 	found com.vladsch.flexmark#flexmark-util-visitor;0.61.34 in central
# 	found com.vladsch.flexmark#flexmark-util-builder;0.61.34 in central
# 	found com.vladsch.flexmark#flexmark-util-dependency;0.61.34 in central
# 	found com.vladsch.flexmark#flexmark-util-format;0.61.34 in central
# 	found com.vladsch.flexmark#flexmark-util-html;0.61.34 in central
# 	found com.vladsch.flexmark#flexmark-ext-abbreviation;0.61.34 in central
# 	found com.vladsch.flexmark#flexmark-util;0.61.34 in central
# 	found com.vladsch.flexmark#flexmark-util-options;0.61.34 in central
# 	found com.vladsch.flexmark#flexmark-ext-autolink;0.61.34 in central
# 	found org.nibor.autolink#autolink;0.6.0 in central
# 	found com.vladsch.flexmark#flexmark-ext-admonition;0.61.34 in central
# 	found com.vladsch.flexmark#flexmark-ext-anchorlink;0.61.34 in central
# 	found com.vladsch.flexmark#flexmark-ext-aside;0.61.34 in central
# 	found com.vladsch.flexmark#flexmark-jira-converter;0.61.34 in central
# 	found com.vladsch.flexmark#flexmark-ext-gfm-strikethrough;0.61.34 in central
# 	found com.vladsch.flexmark#flexmark-ext-tables;0.61.34 in central
# 	found com.vladsch.flexmark#flexmark-ext-wikilink;0.61.34 in central
# 	found com.vladsch.flexmark#flexmark-ext-ins;0.61.34 in central
# 	found com.vladsch.flexmark#flexmark-ext-superscript;0.61.34 in central
# 	found com.vladsch.flexmark#flexmark-ext-attributes;0.61.34 in central
# 	found com.vladsch.flexmark#flexmark-ext-definition;0.61.34 in central
# 	found com.vladsch.flexmark#flexmark-ext-emoji;0.61.34 in central
# 	found com.vladsch.flexmark#flexmark-ext-enumerated-reference;0.61.34 in central
# 	found com.vladsch.flexmark#flexmark-ext-escaped-character;0.61.34 in central
# 	found com.vladsch.flexmark#flexmark-ext-footnotes;0.61.34 in central
# 	found com.vladsch.flexmark#flexmark-ext-gfm-issues;0.61.34 in central
# 	found com.vladsch.flexmark#flexmark-ext-gfm-tasklist;0.61.34 in central
# 	found com.vladsch.flexmark#flexmark-ext-gfm-users;0.61.34 in central
# 	found com.vladsch.flexmark#flexmark-ext-gitlab;0.61.34 in central
# 	found com.vladsch.flexmark#flexmark-ext-jekyll-front-matter;0.61.34 in central
# 	found com.vladsch.flexmark#flexmark-ext-yaml-front-matter;0.61.34 in central
# 	found com.vladsch.flexmark#flexmark-ext-jekyll-tag;0.61.34 in central
# 	found com.vladsch.flexmark#flexmark-ext-media-tags;0.61.34 in central
# 	found com.vladsch.flexmark#flexmark-ext-macros;0.61.34 in central
# 	found com.vladsch.flexmark#flexmark-ext-xwiki-macros;0.61.34 in central
# 	found com.vladsch.flexmark#flexmark-ext-toc;0.61.34 in central
# 	found com.vladsch.flexmark#flexmark-ext-typographic;0.61.34 in central
# 	found com.vladsch.flexmark#flexmark-ext-youtube-embedded;0.61.34 in central
# 	found com.vladsch.flexmark#flexmark-html2md-converter;0.61.34 in central
# 	found com.vladsch.flexmark#flexmark-pdf-converter;0.61.34 in central
# 	found com.openhtmltopdf#openhtmltopdf-core;1.0.0 in central
# 	found com.openhtmltopdf#openhtmltopdf-pdfbox;1.0.0 in central
# 	found org.apache.pdfbox#xmpbox;2.0.16 in central
# 	found de.rototor.pdfbox#graphics2d;0.24 in central
# 	found com.openhtmltopdf#openhtmltopdf-rtl-support;1.0.0 in central
# 	found com.ibm.icu#icu4j;59.1 in central
# 	found com.openhtmltopdf#openhtmltopdf-jsoup-dom-converter;1.0.0 in central
# 	found com.vladsch.flexmark#flexmark-profile-pegdown;0.61.34 in central
# 	found com.vladsch.flexmark#flexmark-youtrack-converter;0.61.34 in central
# 	found com.johnsnowlabs.nlp#tensorflow-cpu_2.12;0.4.4 in central
# 	found com.microsoft.onnxruntime#onnxruntime;1.19.2 in central
# 	found com.johnsnowlabs.nlp#jsl-llamacpp-cpu;1.0.2 in central
# 	found org.jetbrains#annotations;24.1.0 in central
# 	found com.johnsnowlabs.nlp#jsl-openvino-cpu_2.12;0.2.0 in central
# downloading https://repo1.maven.org/maven2/com/johnsnowlabs/nlp/spark-nlp_2.12/6.1.2/spark-nlp_2.12-6.1.2.jar ...
# 	[SUCCESSFUL ] com.johnsnowlabs.nlp#spark-nlp_2.12;6.1.2!spark-nlp_2.12.jar (6269ms)
# downloading https://repo1.maven.org/maven2/com/typesafe/config/1.4.2/config-1.4.2.jar ...
# 	[SUCCESSFUL ] com.typesafe#config;1.4.2!config.jar(bundle) (322ms)
# downloading https://repo1.maven.org/maven2/org/rocksdb/rocksdbjni/6.29.5/rocksdbjni-6.29.5.jar ...
# 	[SUCCESSFUL ] org.rocksdb#rocksdbjni;6.29.5!rocksdbjni.jar (5388ms)
# downloading https://repo1.maven.org/maven2/com/amazonaws/aws-java-sdk-s3/1.12.500/aws-java-sdk-s3-1.12.500.jar ...
# 	[SUCCESSFUL ] com.amazonaws#aws-java-sdk-s3;1.12.500!aws-java-sdk-s3.jar (485ms)
# downloading https://repo1.maven.org/maven2/com/github/universal-automata/liblevenshtein/3.0.0/liblevenshtein-3.0.0.jar ...
# 	[SUCCESSFUL ] com.github.universal-automata#liblevenshtein;3.0.0!liblevenshtein.jar (306ms)
# downloading https://repo1.maven.org/maven2/com/google/cloud/google-cloud-storage/2.20.1/google-cloud-storage-2.20.1.jar ...
# 	[SUCCESSFUL ] com.google.cloud#google-cloud-storage;2.20.1!google-cloud-storage.jar (378ms)
# downloading https://repo1.maven.org/maven2/com/navigamez/greex/1.0/greex-1.0.jar ...
# 	[SUCCESSFUL ] com.navigamez#greex;1.0!greex.jar (300ms)
# downloading https://repo1.maven.org/maven2/org/jsoup/jsoup/1.18.2/jsoup-1.18.2.jar ...
# 	[SUCCESSFUL ] org.jsoup#jsoup;1.18.2!jsoup.jar (364ms)
# downloading https://repo1.maven.org/maven2/jakarta/mail/jakarta.mail-api/2.1.3/jakarta.mail-api-2.1.3.jar ...
# 	[SUCCESSFUL ] jakarta.mail#jakarta.mail-api;2.1.3!jakarta.mail-api.jar (317ms)
# downloading https://repo1.maven.org/maven2/org/eclipse/angus/angus-mail/2.0.3/angus-mail-2.0.3.jar ...
# 	[SUCCESSFUL ] org.eclipse.angus#angus-mail;2.0.3!angus-mail.jar (368ms)
# downloading https://repo1.maven.org/maven2/org/apache/poi/poi-ooxml/4.1.2/poi-ooxml-4.1.2.jar ...
# 	[SUCCESSFUL ] org.apache.poi#poi-ooxml;4.1.2!poi-ooxml.jar (470ms)
# downloading https://repo1.maven.org/maven2/org/apache/poi/poi-scratchpad/4.1.2/poi-scratchpad-4.1.2.jar ...
# 	[SUCCESSFUL ] org.apache.poi#poi-scratchpad;4.1.2!poi-scratchpad.jar (487ms)
# downloading https://repo1.maven.org/maven2/org/apache/pdfbox/pdfbox/2.0.28/pdfbox-2.0.28.jar ...
# 	[SUCCESSFUL ] org.apache.pdfbox#pdfbox;2.0.28!pdfbox.jar(bundle) (553ms)
# downloading https://repo1.maven.org/maven2/com/vladsch/flexmark/flexmark-all/0.61.34/flexmark-all-0.61.34.jar ...
# 	[SUCCESSFUL ] com.vladsch.flexmark#flexmark-all;0.61.34!flexmark-all.jar (304ms)
# downloading https://repo1.maven.org/maven2/com/johnsnowlabs/nlp/tensorflow-cpu_2.12/0.4.4/tensorflow-cpu_2.12-0.4.4.jar ...
# 	[SUCCESSFUL ] com.johnsnowlabs.nlp#tensorflow-cpu_2.12;0.4.4!tensorflow-cpu_2.12.jar (28909ms)
# downloading https://repo1.maven.org/maven2/com/microsoft/onnxruntime/onnxruntime/1.19.2/onnxruntime-1.19.2.jar ...
# 	[SUCCESSFUL ] com.microsoft.onnxruntime#onnxruntime;1.19.2!onnxruntime.jar (9914ms)
# downloading https://repo1.maven.org/maven2/com/johnsnowlabs/nlp/jsl-llamacpp-cpu/1.0.2/jsl-llamacpp-cpu-1.0.2.jar ...
# 	[SUCCESSFUL ] com.johnsnowlabs.nlp#jsl-llamacpp-cpu;1.0.2!jsl-llamacpp-cpu.jar (557ms)
# downloading https://repo1.maven.org/maven2/com/johnsnowlabs/nlp/jsl-openvino-cpu_2.12/0.2.0/jsl-openvino-cpu_2.12-0.2.0.jar ...
# 	[SUCCESSFUL ] com.johnsnowlabs.nlp#jsl-openvino-cpu_2.12;0.2.0!jsl-openvino-cpu_2.12.jar (6313ms)
# downloading https://repo1.maven.org/maven2/com/amazonaws/aws-java-sdk-kms/1.12.500/aws-java-sdk-kms-1.12.500.jar ...
# 	[SUCCESSFUL ] com.amazonaws#aws-java-sdk-kms;1.12.500!aws-java-sdk-kms.jar (365ms)
# downloading https://repo1.maven.org/maven2/com/amazonaws/aws-java-sdk-core/1.12.500/aws-java-sdk-core-1.12.500.jar ...
# 	[SUCCESSFUL ] com.amazonaws#aws-java-sdk-core;1.12.500!aws-java-sdk-core.jar (394ms)
# downloading https://repo1.maven.org/maven2/com/amazonaws/jmespath-java/1.12.500/jmespath-java-1.12.500.jar ...
# 	[SUCCESSFUL ] com.amazonaws#jmespath-java;1.12.500!jmespath-java.jar (307ms)
# downloading https://repo1.maven.org/maven2/commons-logging/commons-logging/1.1.3/commons-logging-1.1.3.jar ...
# 	[SUCCESSFUL ] commons-logging#commons-logging;1.1.3!commons-logging.jar (314ms)
# downloading https://repo1.maven.org/maven2/commons-codec/commons-codec/1.15/commons-codec-1.15.jar ...
# 	[SUCCESSFUL ] commons-codec#commons-codec;1.15!commons-codec.jar (337ms)
# downloading https://repo1.maven.org/maven2/org/apache/httpcomponents/httpclient/4.5.13/httpclient-4.5.13.jar ...
# 	[SUCCESSFUL ] org.apache.httpcomponents#httpclient;4.5.13!httpclient.jar (368ms)
# downloading https://repo1.maven.org/maven2/software/amazon/ion/ion-java/1.0.2/ion-java-1.0.2.jar ...
# 	[SUCCESSFUL ] software.amazon.ion#ion-java;1.0.2!ion-java.jar(bundle) (355ms)
# downloading https://repo1.maven.org/maven2/joda-time/joda-time/2.8.1/joda-time-2.8.1.jar ...
# 	[SUCCESSFUL ] joda-time#joda-time;2.8.1!joda-time.jar (359ms)
# downloading https://repo1.maven.org/maven2/org/apache/httpcomponents/httpcore/4.4.13/httpcore-4.4.13.jar ...
# 	[SUCCESSFUL ] org.apache.httpcomponents#httpcore;4.4.13!httpcore.jar (327ms)
# downloading https://repo1.maven.org/maven2/it/unimi/dsi/fastutil/7.0.12/fastutil-7.0.12.jar ...
# 	[SUCCESSFUL ] it.unimi.dsi#fastutil;7.0.12!fastutil.jar (2248ms)
# downloading https://repo1.maven.org/maven2/org/projectlombok/lombok/1.16.8/lombok-1.16.8.jar ...
# 	[SUCCESSFUL ] org.projectlombok#lombok;1.16.8!lombok.jar (446ms)
# downloading https://repo1.maven.org/maven2/com/google/guava/guava/31.1-jre/guava-31.1-jre.jar ...
# 	[SUCCESSFUL ] com.google.guava#guava;31.1-jre!guava.jar(bundle) (622ms)
# downloading https://repo1.maven.org/maven2/com/google/guava/failureaccess/1.0.1/failureaccess-1.0.1.jar ...
# 	[SUCCESSFUL ] com.google.guava#failureaccess;1.0.1!failureaccess.jar(bundle) (305ms)
# downloading https://repo1.maven.org/maven2/com/google/guava/listenablefuture/9999.0-empty-to-avoid-conflict-with-guava/listenablefuture-9999.0-empty-to-avoid-conflict-with-guava.jar ...
# 	[SUCCESSFUL ] com.google.guava#listenablefuture;9999.0-empty-to-avoid-conflict-with-guava!listenablefuture.jar (307ms)
# downloading https://repo1.maven.org/maven2/com/google/errorprone/error_prone_annotations/2.18.0/error_prone_annotations-2.18.0.jar ...
# 	[SUCCESSFUL ] com.google.errorprone#error_prone_annotations;2.18.0!error_prone_annotations.jar (314ms)
# downloading https://repo1.maven.org/maven2/com/google/j2objc/j2objc-annotations/1.3/j2objc-annotations-1.3.jar ...
# 	[SUCCESSFUL ] com.google.j2objc#j2objc-annotations;1.3!j2objc-annotations.jar (302ms)
# downloading https://repo1.maven.org/maven2/com/google/http-client/google-http-client/1.43.0/google-http-client-1.43.0.jar ...
# 	[SUCCESSFUL ] com.google.http-client#google-http-client;1.43.0!google-http-client.jar (332ms)
# downloading https://repo1.maven.org/maven2/io/opencensus/opencensus-contrib-http-util/0.31.1/opencensus-contrib-http-util-0.31.1.jar ...
# 	[SUCCESSFUL ] io.opencensus#opencensus-contrib-http-util;0.31.1!opencensus-contrib-http-util.jar (309ms)
# downloading https://repo1.maven.org/maven2/com/google/http-client/google-http-client-jackson2/1.43.0/google-http-client-jackson2-1.43.0.jar ...
# 	[SUCCESSFUL ] com.google.http-client#google-http-client-jackson2;1.43.0!google-http-client-jackson2.jar (303ms)
# downloading https://repo1.maven.org/maven2/com/google/http-client/google-http-client-gson/1.43.0/google-http-client-gson-1.43.0.jar ...
# 	[SUCCESSFUL ] com.google.http-client#google-http-client-gson;1.43.0!google-http-client-gson.jar (297ms)
# downloading https://repo1.maven.org/maven2/com/google/api-client/google-api-client/2.2.0/google-api-client-2.2.0.jar ...
# 	[SUCCESSFUL ] com.google.api-client#google-api-client;2.2.0!google-api-client.jar (339ms)
# downloading https://repo1.maven.org/maven2/com/google/oauth-client/google-oauth-client/1.34.1/google-oauth-client-1.34.1.jar ...
# 	[SUCCESSFUL ] com.google.oauth-client#google-oauth-client;1.34.1!google-oauth-client.jar (307ms)
# downloading https://repo1.maven.org/maven2/com/google/http-client/google-http-client-apache-v2/1.43.0/google-http-client-apache-v2-1.43.0.jar ...
# 	[SUCCESSFUL ] com.google.http-client#google-http-client-apache-v2;1.43.0!google-http-client-apache-v2.jar (314ms)
# downloading https://repo1.maven.org/maven2/com/google/apis/google-api-services-storage/v1-rev20220705-2.0.0/google-api-services-storage-v1-rev20220705-2.0.0.jar ...
# 	[SUCCESSFUL ] com.google.apis#google-api-services-storage;v1-rev20220705-2.0.0!google-api-services-storage.jar (309ms)
# downloading https://repo1.maven.org/maven2/com/google/code/gson/gson/2.10.1/gson-2.10.1.jar ...
# 	[SUCCESSFUL ] com.google.code.gson#gson;2.10.1!gson.jar (327ms)
# downloading https://repo1.maven.org/maven2/com/google/cloud/google-cloud-core/2.12.0/google-cloud-core-2.12.0.jar ...
# 	[SUCCESSFUL ] com.google.cloud#google-cloud-core;2.12.0!google-cloud-core.jar (306ms)
# downloading https://repo1.maven.org/maven2/io/grpc/grpc-context/1.53.0/grpc-context-1.53.0.jar ...
# 	[SUCCESSFUL ] io.grpc#grpc-context;1.53.0!grpc-context.jar (301ms)
# downloading https://repo1.maven.org/maven2/com/google/auto/value/auto-value-annotations/1.10.1/auto-value-annotations-1.10.1.jar ...
# 	[SUCCESSFUL ] com.google.auto.value#auto-value-annotations;1.10.1!auto-value-annotations.jar (301ms)
# downloading https://repo1.maven.org/maven2/com/google/auto/value/auto-value/1.10.1/auto-value-1.10.1.jar ...
# 	[SUCCESSFUL ] com.google.auto.value#auto-value;1.10.1!auto-value.jar (818ms)
# downloading https://repo1.maven.org/maven2/javax/annotation/javax.annotation-api/1.3.2/javax.annotation-api-1.3.2.jar ...
# 	[SUCCESSFUL ] javax.annotation#javax.annotation-api;1.3.2!javax.annotation-api.jar (296ms)
# downloading https://repo1.maven.org/maven2/com/google/cloud/google-cloud-core-http/2.12.0/google-cloud-core-http-2.12.0.jar ...
# 	[SUCCESSFUL ] com.google.cloud#google-cloud-core-http;2.12.0!google-cloud-core-http.jar (299ms)
# downloading https://repo1.maven.org/maven2/com/google/http-client/google-http-client-appengine/1.43.0/google-http-client-appengine-1.43.0.jar ...
# 	[SUCCESSFUL ] com.google.http-client#google-http-client-appengine;1.43.0!google-http-client-appengine.jar (318ms)
# downloading https://repo1.maven.org/maven2/com/google/api/gax-httpjson/0.108.2/gax-httpjson-0.108.2.jar ...
# 	[SUCCESSFUL ] com.google.api#gax-httpjson;0.108.2!gax-httpjson.jar (313ms)
# downloading https://repo1.maven.org/maven2/com/google/cloud/google-cloud-core-grpc/2.12.0/google-cloud-core-grpc-2.12.0.jar ...
# 	[SUCCESSFUL ] com.google.cloud#google-cloud-core-grpc;2.12.0!google-cloud-core-grpc.jar (298ms)
# downloading https://repo1.maven.org/maven2/io/grpc/grpc-alts/1.53.0/grpc-alts-1.53.0.jar ...
# 	[SUCCESSFUL ] io.grpc#grpc-alts;1.53.0!grpc-alts.jar (328ms)
# downloading https://repo1.maven.org/maven2/io/grpc/grpc-grpclb/1.53.0/grpc-grpclb-1.53.0.jar ...
# 	[SUCCESSFUL ] io.grpc#grpc-grpclb;1.53.0!grpc-grpclb.jar (315ms)
# downloading https://repo1.maven.org/maven2/org/conscrypt/conscrypt-openjdk-uber/2.5.2/conscrypt-openjdk-uber-2.5.2.jar ...
# 	[SUCCESSFUL ] org.conscrypt#conscrypt-openjdk-uber;2.5.2!conscrypt-openjdk-uber.jar (769ms)
# downloading https://repo1.maven.org/maven2/io/grpc/grpc-auth/1.53.0/grpc-auth-1.53.0.jar ...
# 	[SUCCESSFUL ] io.grpc#grpc-auth;1.53.0!grpc-auth.jar (301ms)
# downloading https://repo1.maven.org/maven2/io/grpc/grpc-protobuf/1.53.0/grpc-protobuf-1.53.0.jar ...
# 	[SUCCESSFUL ] io.grpc#grpc-protobuf;1.53.0!grpc-protobuf.jar (306ms)
# downloading https://repo1.maven.org/maven2/io/grpc/grpc-protobuf-lite/1.53.0/grpc-protobuf-lite-1.53.0.jar ...
# 	[SUCCESSFUL ] io.grpc#grpc-protobuf-lite;1.53.0!grpc-protobuf-lite.jar (305ms)
# downloading https://repo1.maven.org/maven2/io/grpc/grpc-core/1.53.0/grpc-core-1.53.0.jar ...
# 	[SUCCESSFUL ] io.grpc#grpc-core;1.53.0!grpc-core.jar (369ms)
# downloading https://repo1.maven.org/maven2/com/google/api/gax/2.23.2/gax-2.23.2.jar ...
# 	[SUCCESSFUL ] com.google.api#gax;2.23.2!gax.jar (348ms)
# downloading https://repo1.maven.org/maven2/com/google/api/gax-grpc/2.23.2/gax-grpc-2.23.2.jar ...
# 	[SUCCESSFUL ] com.google.api#gax-grpc;2.23.2!gax-grpc.jar (318ms)
# downloading https://repo1.maven.org/maven2/com/google/auth/google-auth-library-credentials/1.16.0/google-auth-library-credentials-1.16.0.jar ...
# 	[SUCCESSFUL ] com.google.auth#google-auth-library-credentials;1.16.0!google-auth-library-credentials.jar (299ms)
# downloading https://repo1.maven.org/maven2/com/google/auth/google-auth-library-oauth2-http/1.16.0/google-auth-library-oauth2-http-1.16.0.jar ...
# 	[SUCCESSFUL ] com.google.auth#google-auth-library-oauth2-http;1.16.0!google-auth-library-oauth2-http.jar (323ms)
# downloading https://repo1.maven.org/maven2/com/google/api/api-common/2.6.2/api-common-2.6.2.jar ...
# 	[SUCCESSFUL ] com.google.api#api-common;2.6.2!api-common.jar (310ms)
# downloading https://repo1.maven.org/maven2/io/opencensus/opencensus-api/0.31.1/opencensus-api-0.31.1.jar ...
# 	[SUCCESSFUL ] io.opencensus#opencensus-api;0.31.1!opencensus-api.jar (335ms)
# downloading https://repo1.maven.org/maven2/com/google/api/grpc/proto-google-iam-v1/1.9.2/proto-google-iam-v1-1.9.2.jar ...
# 	[SUCCESSFUL ] com.google.api.grpc#proto-google-iam-v1;1.9.2!proto-google-iam-v1.jar (308ms)
# downloading https://repo1.maven.org/maven2/com/google/protobuf/protobuf-java/3.21.12/protobuf-java-3.21.12.jar ...
# 	[SUCCESSFUL ] com.google.protobuf#protobuf-java;3.21.12!protobuf-java.jar(bundle) (479ms)
# downloading https://repo1.maven.org/maven2/com/google/protobuf/protobuf-java-util/3.21.12/protobuf-java-util-3.21.12.jar ...
# 	[SUCCESSFUL ] com.google.protobuf#protobuf-java-util;3.21.12!protobuf-java-util.jar(bundle) (310ms)
# downloading https://repo1.maven.org/maven2/com/google/api/grpc/proto-google-common-protos/2.14.2/proto-google-common-protos-2.14.2.jar ...
# 	[SUCCESSFUL ] com.google.api.grpc#proto-google-common-protos;2.14.2!proto-google-common-protos.jar (557ms)
# downloading https://repo1.maven.org/maven2/org/threeten/threetenbp/1.6.5/threetenbp-1.6.5.jar ...
# 	[SUCCESSFUL ] org.threeten#threetenbp;1.6.5!threetenbp.jar (358ms)
# downloading https://repo1.maven.org/maven2/com/google/api/grpc/proto-google-cloud-storage-v2/2.20.1-alpha/proto-google-cloud-storage-v2-2.20.1-alpha.jar ...
# 	[SUCCESSFUL ] com.google.api.grpc#proto-google-cloud-storage-v2;2.20.1-alpha!proto-google-cloud-storage-v2.jar (377ms)
# downloading https://repo1.maven.org/maven2/com/google/api/grpc/grpc-google-cloud-storage-v2/2.20.1-alpha/grpc-google-cloud-storage-v2-2.20.1-alpha.jar ...
# 	[SUCCESSFUL ] com.google.api.grpc#grpc-google-cloud-storage-v2;2.20.1-alpha!grpc-google-cloud-storage-v2.jar (307ms)
# downloading https://repo1.maven.org/maven2/com/google/api/grpc/gapic-google-cloud-storage-v2/2.20.1-alpha/gapic-google-cloud-storage-v2-2.20.1-alpha.jar ...
# 	[SUCCESSFUL ] com.google.api.grpc#gapic-google-cloud-storage-v2;2.20.1-alpha!gapic-google-cloud-storage-v2.jar (310ms)
# downloading https://repo1.maven.org/maven2/com/google/code/findbugs/jsr305/3.0.2/jsr305-3.0.2.jar ...
# 	[SUCCESSFUL ] com.google.code.findbugs#jsr305;3.0.2!jsr305.jar (308ms)
# downloading https://repo1.maven.org/maven2/io/grpc/grpc-api/1.53.0/grpc-api-1.53.0.jar ...
# 	[SUCCESSFUL ] io.grpc#grpc-api;1.53.0!grpc-api.jar (318ms)
# downloading https://repo1.maven.org/maven2/io/grpc/grpc-stub/1.53.0/grpc-stub-1.53.0.jar ...
# 	[SUCCESSFUL ] io.grpc#grpc-stub;1.53.0!grpc-stub.jar (318ms)
# downloading https://repo1.maven.org/maven2/org/checkerframework/checker-qual/3.31.0/checker-qual-3.31.0.jar ...
# 	[SUCCESSFUL ] org.checkerframework#checker-qual;3.31.0!checker-qual.jar (358ms)
# downloading https://repo1.maven.org/maven2/io/perfmark/perfmark-api/0.26.0/perfmark-api-0.26.0.jar ...
# 	[SUCCESSFUL ] io.perfmark#perfmark-api;0.26.0!perfmark-api.jar (330ms)
# downloading https://repo1.maven.org/maven2/com/google/android/annotations/4.1.1.4/annotations-4.1.1.4.jar ...
# 	[SUCCESSFUL ] com.google.android#annotations;4.1.1.4!annotations.jar (297ms)
# downloading https://repo1.maven.org/maven2/org/codehaus/mojo/animal-sniffer-annotations/1.22/animal-sniffer-annotations-1.22.jar ...
# 	[SUCCESSFUL ] org.codehaus.mojo#animal-sniffer-annotations;1.22!animal-sniffer-annotations.jar (301ms)
# downloading https://repo1.maven.org/maven2/io/opencensus/opencensus-proto/0.2.0/opencensus-proto-0.2.0.jar ...
# 	[SUCCESSFUL ] io.opencensus#opencensus-proto;0.2.0!opencensus-proto.jar (372ms)
# downloading https://repo1.maven.org/maven2/io/grpc/grpc-services/1.53.0/grpc-services-1.53.0.jar ...
# 	[SUCCESSFUL ] io.grpc#grpc-services;1.53.0!grpc-services.jar (369ms)
# downloading https://repo1.maven.org/maven2/com/google/re2j/re2j/1.6/re2j-1.6.jar ...
# 	[SUCCESSFUL ] com.google.re2j#re2j;1.6!re2j.jar (317ms)
# downloading https://repo1.maven.org/maven2/io/grpc/grpc-netty-shaded/1.53.0/grpc-netty-shaded-1.53.0.jar ...
# 	[SUCCESSFUL ] io.grpc#grpc-netty-shaded;1.53.0!grpc-netty-shaded.jar (1297ms)
# downloading https://repo1.maven.org/maven2/io/grpc/grpc-googleapis/1.53.0/grpc-googleapis-1.53.0.jar ...
# 	[SUCCESSFUL ] io.grpc#grpc-googleapis;1.53.0!grpc-googleapis.jar (312ms)
# downloading https://repo1.maven.org/maven2/io/grpc/grpc-xds/1.53.0/grpc-xds-1.53.0.jar ...
# 	[SUCCESSFUL ] io.grpc#grpc-xds;1.53.0!grpc-xds.jar (1543ms)
# downloading https://repo1.maven.org/maven2/dk/brics/automaton/automaton/1.11-8/automaton-1.11-8.jar ...
# 	[SUCCESSFUL ] dk.brics.automaton#automaton;1.11-8!automaton.jar (322ms)
# downloading https://repo1.maven.org/maven2/jakarta/activation/jakarta.activation-api/2.1.3/jakarta.activation-api-2.1.3.jar ...
# 	[SUCCESSFUL ] jakarta.activation#jakarta.activation-api;2.1.3!jakarta.activation-api.jar (316ms)
# downloading https://repo1.maven.org/maven2/org/eclipse/angus/angus-activation/2.0.2/angus-activation-2.0.2.jar ...
# 	[SUCCESSFUL ] org.eclipse.angus#angus-activation;2.0.2!angus-activation.jar (301ms)
# downloading https://repo1.maven.org/maven2/org/apache/poi/poi/4.1.2/poi-4.1.2.jar ...
# 	[SUCCESSFUL ] org.apache.poi#poi;4.1.2!poi.jar (613ms)
# downloading https://repo1.maven.org/maven2/org/apache/poi/poi-ooxml-schemas/4.1.2/poi-ooxml-schemas-4.1.2.jar ...
# 	[SUCCESSFUL ] org.apache.poi#poi-ooxml-schemas;4.1.2!poi-ooxml-schemas.jar (1088ms)
# downloading https://repo1.maven.org/maven2/org/apache/commons/commons-compress/1.19/commons-compress-1.19.jar ...
# 	[SUCCESSFUL ] org.apache.commons#commons-compress;1.19!commons-compress.jar (349ms)
# downloading https://repo1.maven.org/maven2/com/github/virtuald/curvesapi/1.06/curvesapi-1.06.jar ...
# 	[SUCCESSFUL ] com.github.virtuald#curvesapi;1.06!curvesapi.jar (317ms)
# downloading https://repo1.maven.org/maven2/org/apache/commons/commons-collections4/4.4/commons-collections4-4.4.jar ...
# 	[SUCCESSFUL ] org.apache.commons#commons-collections4;4.4!commons-collections4.jar (358ms)
# downloading https://repo1.maven.org/maven2/org/apache/commons/commons-math3/3.6.1/commons-math3-3.6.1.jar ...
# 	[SUCCESSFUL ] org.apache.commons#commons-math3;3.6.1!commons-math3.jar (510ms)
# downloading https://repo1.maven.org/maven2/com/zaxxer/SparseBitSet/1.2/SparseBitSet-1.2.jar ...
# 	[SUCCESSFUL ] com.zaxxer#SparseBitSet;1.2!SparseBitSet.jar (294ms)
# downloading https://repo1.maven.org/maven2/org/apache/xmlbeans/xmlbeans/3.1.0/xmlbeans-3.1.0.jar ...
# 	[SUCCESSFUL ] org.apache.xmlbeans#xmlbeans;3.1.0!xmlbeans.jar (554ms)
# downloading https://repo1.maven.org/maven2/org/apache/pdfbox/fontbox/2.0.28/fontbox-2.0.28.jar ...
# 	[SUCCESSFUL ] org.apache.pdfbox#fontbox;2.0.28!fontbox.jar(bundle) (472ms)
# downloading https://repo1.maven.org/maven2/com/vladsch/flexmark/flexmark/0.61.34/flexmark-0.61.34.jar ...
# 	[SUCCESSFUL ] com.vladsch.flexmark#flexmark;0.61.34!flexmark.jar (388ms)
# downloading https://repo1.maven.org/maven2/com/vladsch/flexmark/flexmark-ext-abbreviation/0.61.34/flexmark-ext-abbreviation-0.61.34.jar ...
# 	[SUCCESSFUL ] com.vladsch.flexmark#flexmark-ext-abbreviation;0.61.34!flexmark-ext-abbreviation.jar (298ms)
# downloading https://repo1.maven.org/maven2/com/vladsch/flexmark/flexmark-ext-admonition/0.61.34/flexmark-ext-admonition-0.61.34.jar ...
# 	[SUCCESSFUL ] com.vladsch.flexmark#flexmark-ext-admonition;0.61.34!flexmark-ext-admonition.jar (297ms)
# downloading https://repo1.maven.org/maven2/com/vladsch/flexmark/flexmark-ext-anchorlink/0.61.34/flexmark-ext-anchorlink-0.61.34.jar ...
# 	[SUCCESSFUL ] com.vladsch.flexmark#flexmark-ext-anchorlink;0.61.34!flexmark-ext-anchorlink.jar (308ms)
# downloading https://repo1.maven.org/maven2/com/vladsch/flexmark/flexmark-ext-aside/0.61.34/flexmark-ext-aside-0.61.34.jar ...
# 	[SUCCESSFUL ] com.vladsch.flexmark#flexmark-ext-aside;0.61.34!flexmark-ext-aside.jar (306ms)
# downloading https://repo1.maven.org/maven2/com/vladsch/flexmark/flexmark-ext-attributes/0.61.34/flexmark-ext-attributes-0.61.34.jar ...
# 	[SUCCESSFUL ] com.vladsch.flexmark#flexmark-ext-attributes;0.61.34!flexmark-ext-attributes.jar (323ms)
# downloading https://repo1.maven.org/maven2/com/vladsch/flexmark/flexmark-ext-autolink/0.61.34/flexmark-ext-autolink-0.61.34.jar ...
# 	[SUCCESSFUL ] com.vladsch.flexmark#flexmark-ext-autolink;0.61.34!flexmark-ext-autolink.jar (303ms)
# downloading https://repo1.maven.org/maven2/com/vladsch/flexmark/flexmark-ext-definition/0.61.34/flexmark-ext-definition-0.61.34.jar ...
# 	[SUCCESSFUL ] com.vladsch.flexmark#flexmark-ext-definition;0.61.34!flexmark-ext-definition.jar (307ms)
# downloading https://repo1.maven.org/maven2/com/vladsch/flexmark/flexmark-ext-emoji/0.61.34/flexmark-ext-emoji-0.61.34.jar ...
# 	[SUCCESSFUL ] com.vladsch.flexmark#flexmark-ext-emoji;0.61.34!flexmark-ext-emoji.jar (310ms)
# downloading https://repo1.maven.org/maven2/com/vladsch/flexmark/flexmark-ext-enumerated-reference/0.61.34/flexmark-ext-enumerated-reference-0.61.34.jar ...
# 	[SUCCESSFUL ] com.vladsch.flexmark#flexmark-ext-enumerated-reference;0.61.34!flexmark-ext-enumerated-reference.jar (309ms)
# downloading https://repo1.maven.org/maven2/com/vladsch/flexmark/flexmark-ext-escaped-character/0.61.34/flexmark-ext-escaped-character-0.61.34.jar ...
# 	[SUCCESSFUL ] com.vladsch.flexmark#flexmark-ext-escaped-character;0.61.34!flexmark-ext-escaped-character.jar (295ms)
# downloading https://repo1.maven.org/maven2/com/vladsch/flexmark/flexmark-ext-footnotes/0.61.34/flexmark-ext-footnotes-0.61.34.jar ...
# 	[SUCCESSFUL ] com.vladsch.flexmark#flexmark-ext-footnotes;0.61.34!flexmark-ext-footnotes.jar (300ms)
# downloading https://repo1.maven.org/maven2/com/vladsch/flexmark/flexmark-ext-gfm-issues/0.61.34/flexmark-ext-gfm-issues-0.61.34.jar ...
# 	[SUCCESSFUL ] com.vladsch.flexmark#flexmark-ext-gfm-issues;0.61.34!flexmark-ext-gfm-issues.jar (302ms)
# downloading https://repo1.maven.org/maven2/com/vladsch/flexmark/flexmark-ext-gfm-strikethrough/0.61.34/flexmark-ext-gfm-strikethrough-0.61.34.jar ...
# 	[SUCCESSFUL ] com.vladsch.flexmark#flexmark-ext-gfm-strikethrough;0.61.34!flexmark-ext-gfm-strikethrough.jar (356ms)
# downloading https://repo1.maven.org/maven2/com/vladsch/flexmark/flexmark-ext-gfm-tasklist/0.61.34/flexmark-ext-gfm-tasklist-0.61.34.jar ...
# 	[SUCCESSFUL ] com.vladsch.flexmark#flexmark-ext-gfm-tasklist;0.61.34!flexmark-ext-gfm-tasklist.jar (308ms)
# downloading https://repo1.maven.org/maven2/com/vladsch/flexmark/flexmark-ext-gfm-users/0.61.34/flexmark-ext-gfm-users-0.61.34.jar ...
# 	[SUCCESSFUL ] com.vladsch.flexmark#flexmark-ext-gfm-users;0.61.34!flexmark-ext-gfm-users.jar (297ms)
# downloading https://repo1.maven.org/maven2/com/vladsch/flexmark/flexmark-ext-gitlab/0.61.34/flexmark-ext-gitlab-0.61.34.jar ...
# 	[SUCCESSFUL ] com.vladsch.flexmark#flexmark-ext-gitlab;0.61.34!flexmark-ext-gitlab.jar (299ms)
# downloading https://repo1.maven.org/maven2/com/vladsch/flexmark/flexmark-ext-jekyll-front-matter/0.61.34/flexmark-ext-jekyll-front-matter-0.61.34.jar ...
# 	[SUCCESSFUL ] com.vladsch.flexmark#flexmark-ext-jekyll-front-matter;0.61.34!flexmark-ext-jekyll-front-matter.jar (345ms)
# downloading https://repo1.maven.org/maven2/com/vladsch/flexmark/flexmark-ext-jekyll-tag/0.61.34/flexmark-ext-jekyll-tag-0.61.34.jar ...
# 	[SUCCESSFUL ] com.vladsch.flexmark#flexmark-ext-jekyll-tag;0.61.34!flexmark-ext-jekyll-tag.jar (312ms)
# downloading https://repo1.maven.org/maven2/com/vladsch/flexmark/flexmark-ext-media-tags/0.61.34/flexmark-ext-media-tags-0.61.34.jar ...
# 	[SUCCESSFUL ] com.vladsch.flexmark#flexmark-ext-media-tags;0.61.34!flexmark-ext-media-tags.jar (316ms)
# downloading https://repo1.maven.org/maven2/com/vladsch/flexmark/flexmark-ext-macros/0.61.34/flexmark-ext-macros-0.61.34.jar ...
# 	[SUCCESSFUL ] com.vladsch.flexmark#flexmark-ext-macros;0.61.34!flexmark-ext-macros.jar (298ms)
# downloading https://repo1.maven.org/maven2/com/vladsch/flexmark/flexmark-ext-ins/0.61.34/flexmark-ext-ins-0.61.34.jar ...
# 	[SUCCESSFUL ] com.vladsch.flexmark#flexmark-ext-ins;0.61.34!flexmark-ext-ins.jar (309ms)
# downloading https://repo1.maven.org/maven2/com/vladsch/flexmark/flexmark-ext-xwiki-macros/0.61.34/flexmark-ext-xwiki-macros-0.61.34.jar ...
# 	[SUCCESSFUL ] com.vladsch.flexmark#flexmark-ext-xwiki-macros;0.61.34!flexmark-ext-xwiki-macros.jar (307ms)
# downloading https://repo1.maven.org/maven2/com/vladsch/flexmark/flexmark-ext-superscript/0.61.34/flexmark-ext-superscript-0.61.34.jar ...
# 	[SUCCESSFUL ] com.vladsch.flexmark#flexmark-ext-superscript;0.61.34!flexmark-ext-superscript.jar (308ms)
# downloading https://repo1.maven.org/maven2/com/vladsch/flexmark/flexmark-ext-tables/0.61.34/flexmark-ext-tables-0.61.34.jar ...
# 	[SUCCESSFUL ] com.vladsch.flexmark#flexmark-ext-tables;0.61.34!flexmark-ext-tables.jar (307ms)
# downloading https://repo1.maven.org/maven2/com/vladsch/flexmark/flexmark-ext-toc/0.61.34/flexmark-ext-toc-0.61.34.jar ...
# 	[SUCCESSFUL ] com.vladsch.flexmark#flexmark-ext-toc;0.61.34!flexmark-ext-toc.jar (309ms)
# downloading https://repo1.maven.org/maven2/com/vladsch/flexmark/flexmark-ext-typographic/0.61.34/flexmark-ext-typographic-0.61.34.jar ...
# 	[SUCCESSFUL ] com.vladsch.flexmark#flexmark-ext-typographic;0.61.34!flexmark-ext-typographic.jar (298ms)
# downloading https://repo1.maven.org/maven2/com/vladsch/flexmark/flexmark-ext-wikilink/0.61.34/flexmark-ext-wikilink-0.61.34.jar ...
# 	[SUCCESSFUL ] com.vladsch.flexmark#flexmark-ext-wikilink;0.61.34!flexmark-ext-wikilink.jar (306ms)
# downloading https://repo1.maven.org/maven2/com/vladsch/flexmark/flexmark-ext-yaml-front-matter/0.61.34/flexmark-ext-yaml-front-matter-0.61.34.jar ...
# 	[SUCCESSFUL ] com.vladsch.flexmark#flexmark-ext-yaml-front-matter;0.61.34!flexmark-ext-yaml-front-matter.jar (301ms)
# downloading https://repo1.maven.org/maven2/com/vladsch/flexmark/flexmark-ext-youtube-embedded/0.61.34/flexmark-ext-youtube-embedded-0.61.34.jar ...
# 	[SUCCESSFUL ] com.vladsch.flexmark#flexmark-ext-youtube-embedded;0.61.34!flexmark-ext-youtube-embedded.jar (299ms)
# downloading https://repo1.maven.org/maven2/com/vladsch/flexmark/flexmark-html2md-converter/0.61.34/flexmark-html2md-converter-0.61.34.jar ...
# 	[SUCCESSFUL ] com.vladsch.flexmark#flexmark-html2md-converter;0.61.34!flexmark-html2md-converter.jar (307ms)
# downloading https://repo1.maven.org/maven2/com/vladsch/flexmark/flexmark-jira-converter/0.61.34/flexmark-jira-converter-0.61.34.jar ...
# 	[SUCCESSFUL ] com.vladsch.flexmark#flexmark-jira-converter;0.61.34!flexmark-jira-converter.jar (300ms)
# downloading https://repo1.maven.org/maven2/com/vladsch/flexmark/flexmark-pdf-converter/0.61.34/flexmark-pdf-converter-0.61.34.jar ...
# 	[SUCCESSFUL ] com.vladsch.flexmark#flexmark-pdf-converter;0.61.34!flexmark-pdf-converter.jar (361ms)
# downloading https://repo1.maven.org/maven2/com/vladsch/flexmark/flexmark-profile-pegdown/0.61.34/flexmark-profile-pegdown-0.61.34.jar ...
# 	[SUCCESSFUL ] com.vladsch.flexmark#flexmark-profile-pegdown;0.61.34!flexmark-profile-pegdown.jar (307ms)
# downloading https://repo1.maven.org/maven2/com/vladsch/flexmark/flexmark-util-ast/0.61.34/flexmark-util-ast-0.61.34.jar ...
# 	[SUCCESSFUL ] com.vladsch.flexmark#flexmark-util-ast;0.61.34!flexmark-util-ast.jar (315ms)
# downloading https://repo1.maven.org/maven2/com/vladsch/flexmark/flexmark-util-builder/0.61.34/flexmark-util-builder-0.61.34.jar ...
# 	[SUCCESSFUL ] com.vladsch.flexmark#flexmark-util-builder;0.61.34!flexmark-util-builder.jar (305ms)
# downloading https://repo1.maven.org/maven2/com/vladsch/flexmark/flexmark-util-collection/0.61.34/flexmark-util-collection-0.61.34.jar ...
# 	[SUCCESSFUL ] com.vladsch.flexmark#flexmark-util-collection;0.61.34!flexmark-util-collection.jar (317ms)
# downloading https://repo1.maven.org/maven2/com/vladsch/flexmark/flexmark-util-data/0.61.34/flexmark-util-data-0.61.34.jar ...
# 	[SUCCESSFUL ] com.vladsch.flexmark#flexmark-util-data;0.61.34!flexmark-util-data.jar (306ms)
# downloading https://repo1.maven.org/maven2/com/vladsch/flexmark/flexmark-util-dependency/0.61.34/flexmark-util-dependency-0.61.34.jar ...
# 	[SUCCESSFUL ] com.vladsch.flexmark#flexmark-util-dependency;0.61.34!flexmark-util-dependency.jar (296ms)
# downloading https://repo1.maven.org/maven2/com/vladsch/flexmark/flexmark-util-format/0.61.34/flexmark-util-format-0.61.34.jar ...
# 	[SUCCESSFUL ] com.vladsch.flexmark#flexmark-util-format;0.61.34!flexmark-util-format.jar (381ms)
# downloading https://repo1.maven.org/maven2/com/vladsch/flexmark/flexmark-util-html/0.61.34/flexmark-util-html-0.61.34.jar ...
# 	[SUCCESSFUL ] com.vladsch.flexmark#flexmark-util-html;0.61.34!flexmark-util-html.jar (314ms)
# downloading https://repo1.maven.org/maven2/com/vladsch/flexmark/flexmark-util-misc/0.61.34/flexmark-util-misc-0.61.34.jar ...
# 	[SUCCESSFUL ] com.vladsch.flexmark#flexmark-util-misc;0.61.34!flexmark-util-misc.jar (317ms)
# downloading https://repo1.maven.org/maven2/com/vladsch/flexmark/flexmark-util-options/0.61.34/flexmark-util-options-0.61.34.jar ...
# 	[SUCCESSFUL ] com.vladsch.flexmark#flexmark-util-options;0.61.34!flexmark-util-options.jar (306ms)
# downloading https://repo1.maven.org/maven2/com/vladsch/flexmark/flexmark-util-sequence/0.61.34/flexmark-util-sequence-0.61.34.jar ...
# 	[SUCCESSFUL ] com.vladsch.flexmark#flexmark-util-sequence;0.61.34!flexmark-util-sequence.jar (318ms)
# downloading https://repo1.maven.org/maven2/com/vladsch/flexmark/flexmark-util-visitor/0.61.34/flexmark-util-visitor-0.61.34.jar ...
# 	[SUCCESSFUL ] com.vladsch.flexmark#flexmark-util-visitor;0.61.34!flexmark-util-visitor.jar (298ms)
# downloading https://repo1.maven.org/maven2/com/vladsch/flexmark/flexmark-youtrack-converter/0.61.34/flexmark-youtrack-converter-0.61.34.jar ...
# 	[SUCCESSFUL ] com.vladsch.flexmark#flexmark-youtrack-converter;0.61.34!flexmark-youtrack-converter.jar (309ms)
# downloading https://repo1.maven.org/maven2/com/vladsch/flexmark/flexmark-util/0.61.34/flexmark-util-0.61.34.jar ...
# 	[SUCCESSFUL ] com.vladsch.flexmark#flexmark-util;0.61.34!flexmark-util.jar (308ms)
# downloading https://repo1.maven.org/maven2/org/nibor/autolink/autolink/0.6.0/autolink-0.6.0.jar ...
# 	[SUCCESSFUL ] org.nibor.autolink#autolink;0.6.0!autolink.jar (297ms)
# downloading https://repo1.maven.org/maven2/com/openhtmltopdf/openhtmltopdf-core/1.0.0/openhtmltopdf-core-1.0.0.jar ...
# 	[SUCCESSFUL ] com.openhtmltopdf#openhtmltopdf-core;1.0.0!openhtmltopdf-core.jar (418ms)
# downloading https://repo1.maven.org/maven2/com/openhtmltopdf/openhtmltopdf-pdfbox/1.0.0/openhtmltopdf-pdfbox-1.0.0.jar ...
# 	[SUCCESSFUL ] com.openhtmltopdf#openhtmltopdf-pdfbox;1.0.0!openhtmltopdf-pdfbox.jar (327ms)
# downloading https://repo1.maven.org/maven2/com/openhtmltopdf/openhtmltopdf-rtl-support/1.0.0/openhtmltopdf-rtl-support-1.0.0.jar ...
# 	[SUCCESSFUL ] com.openhtmltopdf#openhtmltopdf-rtl-support;1.0.0!openhtmltopdf-rtl-support.jar (298ms)
# downloading https://repo1.maven.org/maven2/com/openhtmltopdf/openhtmltopdf-jsoup-dom-converter/1.0.0/openhtmltopdf-jsoup-dom-converter-1.0.0.jar ...
# 	[SUCCESSFUL ] com.openhtmltopdf#openhtmltopdf-jsoup-dom-converter;1.0.0!openhtmltopdf-jsoup-dom-converter.jar (306ms)
# downloading https://repo1.maven.org/maven2/org/apache/pdfbox/xmpbox/2.0.16/xmpbox-2.0.16.jar ...
# 	[SUCCESSFUL ] org.apache.pdfbox#xmpbox;2.0.16!xmpbox.jar(bundle) (325ms)
# downloading https://repo1.maven.org/maven2/de/rototor/pdfbox/graphics2d/0.24/graphics2d-0.24.jar ...
# 	[SUCCESSFUL ] de.rototor.pdfbox#graphics2d;0.24!graphics2d.jar (299ms)
# downloading https://repo1.maven.org/maven2/com/ibm/icu/icu4j/59.1/icu4j-59.1.jar ...
# 	[SUCCESSFUL ] com.ibm.icu#icu4j;59.1!icu4j.jar (1448ms)
# downloading https://repo1.maven.org/maven2/org/jetbrains/annotations/24.1.0/annotations-24.1.0.jar ...
# 	[SUCCESSFUL ] org.jetbrains#annotations;24.1.0!annotations.jar (301ms)
# :: resolution report :: resolve 122131ms :: artifacts dl 114440ms
# 	:: modules in use:
# 	com.amazonaws#aws-java-sdk-core;1.12.500 from central in [default]
# 	com.amazonaws#aws-java-sdk-kms;1.12.500 from central in [default]
# 	com.amazonaws#aws-java-sdk-s3;1.12.500 from central in [default]
# 	com.amazonaws#jmespath-java;1.12.500 from central in [default]
# 	com.github.universal-automata#liblevenshtein;3.0.0 from central in [default]
# 	com.github.virtuald#curvesapi;1.06 from central in [default]
# 	com.google.android#annotations;4.1.1.4 from central in [default]
# 	com.google.api#api-common;2.6.2 from central in [default]
# 	com.google.api#gax;2.23.2 from central in [default]
# 	com.google.api#gax-grpc;2.23.2 from central in [default]
# 	com.google.api#gax-httpjson;0.108.2 from central in [default]
# 	com.google.api-client#google-api-client;2.2.0 from central in [default]
# 	com.google.api.grpc#gapic-google-cloud-storage-v2;2.20.1-alpha from central in [default]
# 	com.google.api.grpc#grpc-google-cloud-storage-v2;2.20.1-alpha from central in [default]
# 	com.google.api.grpc#proto-google-cloud-storage-v2;2.20.1-alpha from central in [default]
# 	com.google.api.grpc#proto-google-common-protos;2.14.2 from central in [default]
# 	com.google.api.grpc#proto-google-iam-v1;1.9.2 from central in [default]
# 	com.google.apis#google-api-services-storage;v1-rev20220705-2.0.0 from central in [default]
# 	com.google.auth#google-auth-library-credentials;1.16.0 from central in [default]
# 	com.google.auth#google-auth-library-oauth2-http;1.16.0 from central in [default]
# 	com.google.auto.value#auto-value;1.10.1 from central in [default]
# 	com.google.auto.value#auto-value-annotations;1.10.1 from central in [default]
# 	com.google.cloud#google-cloud-core;2.12.0 from central in [default]
# 	com.google.cloud#google-cloud-core-grpc;2.12.0 from central in [default]
# 	com.google.cloud#google-cloud-core-http;2.12.0 from central in [default]
# 	com.google.cloud#google-cloud-storage;2.20.1 from central in [default]
# 	com.google.code.findbugs#jsr305;3.0.2 from central in [default]
# 	com.google.code.gson#gson;2.10.1 from central in [default]
# 	com.google.errorprone#error_prone_annotations;2.18.0 from central in [default]
# 	com.google.guava#failureaccess;1.0.1 from central in [default]
# 	com.google.guava#guava;31.1-jre from central in [default]
# 	com.google.guava#listenablefuture;9999.0-empty-to-avoid-conflict-with-guava from central in [default]
# 	com.google.http-client#google-http-client;1.43.0 from central in [default]
# 	com.google.http-client#google-http-client-apache-v2;1.43.0 from central in [default]
# 	com.google.http-client#google-http-client-appengine;1.43.0 from central in [default]
# 	com.google.http-client#google-http-client-gson;1.43.0 from central in [default]
# 	com.google.http-client#google-http-client-jackson2;1.43.0 from central in [default]
# 	com.google.j2objc#j2objc-annotations;1.3 from central in [default]
# 	com.google.oauth-client#google-oauth-client;1.34.1 from central in [default]
# 	com.google.protobuf#protobuf-java;3.21.12 from central in [default]
# 	com.google.protobuf#protobuf-java-util;3.21.12 from central in [default]
# 	com.google.re2j#re2j;1.6 from central in [default]
# 	com.ibm.icu#icu4j;59.1 from central in [default]
# 	com.johnsnowlabs.nlp#jsl-llamacpp-cpu;1.0.2 from central in [default]
# 	com.johnsnowlabs.nlp#jsl-openvino-cpu_2.12;0.2.0 from central in [default]
# 	com.johnsnowlabs.nlp#spark-nlp_2.12;6.1.2 from central in [default]
# 	com.johnsnowlabs.nlp#tensorflow-cpu_2.12;0.4.4 from central in [default]
# 	com.microsoft.onnxruntime#onnxruntime;1.19.2 from central in [default]
# 	com.navigamez#greex;1.0 from central in [default]
# 	com.openhtmltopdf#openhtmltopdf-core;1.0.0 from central in [default]
# 	com.openhtmltopdf#openhtmltopdf-jsoup-dom-converter;1.0.0 from central in [default]
# 	com.openhtmltopdf#openhtmltopdf-pdfbox;1.0.0 from central in [default]
# 	com.openhtmltopdf#openhtmltopdf-rtl-support;1.0.0 from central in [default]
# 	com.typesafe#config;1.4.2 from central in [default]
# 	com.vladsch.flexmark#flexmark;0.61.34 from central in [default]
# 	com.vladsch.flexmark#flexmark-all;0.61.34 from central in [default]
# 	com.vladsch.flexmark#flexmark-ext-abbreviation;0.61.34 from central in [default]
# 	com.vladsch.flexmark#flexmark-ext-admonition;0.61.34 from central in [default]
# 	com.vladsch.flexmark#flexmark-ext-anchorlink;0.61.34 from central in [default]
# 	com.vladsch.flexmark#flexmark-ext-aside;0.61.34 from central in [default]
# 	com.vladsch.flexmark#flexmark-ext-attributes;0.61.34 from central in [default]
# 	com.vladsch.flexmark#flexmark-ext-autolink;0.61.34 from central in [default]
# 	com.vladsch.flexmark#flexmark-ext-definition;0.61.34 from central in [default]
# 	com.vladsch.flexmark#flexmark-ext-emoji;0.61.34 from central in [default]
# 	com.vladsch.flexmark#flexmark-ext-enumerated-reference;0.61.34 from central in [default]
# 	com.vladsch.flexmark#flexmark-ext-escaped-character;0.61.34 from central in [default]
# 	com.vladsch.flexmark#flexmark-ext-footnotes;0.61.34 from central in [default]
# 	com.vladsch.flexmark#flexmark-ext-gfm-issues;0.61.34 from central in [default]
# 	com.vladsch.flexmark#flexmark-ext-gfm-strikethrough;0.61.34 from central in [default]
# 	com.vladsch.flexmark#flexmark-ext-gfm-tasklist;0.61.34 from central in [default]
# 	com.vladsch.flexmark#flexmark-ext-gfm-users;0.61.34 from central in [default]
# 	com.vladsch.flexmark#flexmark-ext-gitlab;0.61.34 from central in [default]
# 	com.vladsch.flexmark#flexmark-ext-ins;0.61.34 from central in [default]
# 	com.vladsch.flexmark#flexmark-ext-jekyll-front-matter;0.61.34 from central in [default]
# 	com.vladsch.flexmark#flexmark-ext-jekyll-tag;0.61.34 from central in [default]
# ...
# 12:47:42.322 [Thread-4] INFO  org.apache.spark.util.Utils - /tmp/spark-55f4f8c7-2dcc-4759-bdff-34d5ce613e83/userFiles-a2ea4a13-9974-47e4-92e6-bb48b6c59fc7/fetchFileTemp618792299620589227.tmp has been previously copied to /tmp/spark-55f4f8c7-2dcc-4759-bdff-34d5ce613e83/userFiles-a2ea4a13-9974-47e4-92e6-bb48b6c59fc7/com.google.android_annotations-4.1.1.4.jar
# 12:47:42.324 [Thread-4] INFO  org.apache.spark.executor.Executor - Adding file:/tmp/spark-55f4f8c7-2dcc-4759-bdff-34d5ce613e83/userFiles-a2ea4a13-9974-47e4-92e6-bb48b6c59fc7/com.google.android_annotations-4.1.1.4.jar to class loader default
# 12:47:42.324 [Thread-4] INFO  org.apache.spark.executor.Executor - Fetching spark://spark-master:7081/jars/com.google.api_api-common-2.6.2.jar with timestamp 1757854055526
# 12:47:42.324 [Thread-4] INFO  org.apache.spark.util.Utils - Fetching spark://spark-master:7081/jars/com.google.api_api-common-2.6.2.jar to /tmp/spark-55f4f8c7-2dcc-4759-bdff-34d5ce613e83/userFiles-a2ea4a13-9974-47e4-92e6-bb48b6c59fc7/fetchFileTemp4657536280994069412.tmp
# 12:47:42.325 [Thread-4] INFO  org.apache.spark.util.Utils - /tmp/spark-55f4f8c7-2dcc-4759-bdff-34d5ce613e83/userFiles-a2ea4a13-9974-47e4-92e6-bb48b6c59fc7/fetchFileTemp4657536280994069412.tmp has been previously copied to /tmp/spark-55f4f8c7-2dcc-4759-bdff-34d5ce613e83/userFiles-a2ea4a13-9974-47e4-92e6-bb48b6c59fc7/com.google.api_api-common-2.6.2.jar
# 12:47:42.326 [Thread-4] INFO  org.apache.spark.executor.Executor - Adding file:/tmp/spark-55f4f8c7-2dcc-4759-bdff-34d5ce613e83/userFiles-a2ea4a13-9974-47e4-92e6-bb48b6c59fc7/com.google.api_api-common-2.6.2.jar to class loader default
# 12:47:42.327 [Thread-4] INFO  org.apache.spark.executor.Executor - Fetching spark://spark-master:7081/jars/com.vladsch.flexmark_flexmark-ext-superscript-0.61.34.jar with timestamp 1757854055526
# 12:47:42.327 [Thread-4] INFO  org.apache.spark.util.Utils - Fetching spark://spark-master:7081/jars/com.vladsch.flexmark_flexmark-ext-superscript-0.61.34.jar to /tmp/spark-55f4f8c7-2dcc-4759-bdff-34d5ce613e83/userFiles-a2ea4a13-9974-47e4-92e6-bb48b6c59fc7/fetchFileTemp14020019834666964196.tmp
# 12:47:42.327 [Thread-4] INFO  org.apache.spark.util.Utils - /tmp/spark-55f4f8c7-2dcc-4759-bdff-34d5ce613e83/userFiles-a2ea4a13-9974-47e4-92e6-bb48b6c59fc7/fetchFileTemp14020019834666964196.tmp has been previously copied to /tmp/spark-55f4f8c7-2dcc-4759-bdff-34d5ce613e83/userFiles-a2ea4a13-9974-47e4-92e6-bb48b6c59fc7/com.vladsch.flexmark_flexmark-ext-superscript-0.61.34.jar
# 12:47:42.329 [Thread-4] INFO  org.apache.spark.executor.Executor - Adding file:/tmp/spark-55f4f8c7-2dcc-4759-bdff-34d5ce613e83/userFiles-a2ea4a13-9974-47e4-92e6-bb48b6c59fc7/com.vladsch.flexmark_flexmark-ext-superscript-0.61.34.jar to class loader default
# 12:47:42.329 [Thread-4] INFO  org.apache.spark.executor.Executor - Fetching spark://spark-master:7081/jars/com.vladsch.flexmark_flexmark-util-sequence-0.61.34.jar with timestamp 1757854055526
# 12:47:42.329 [Thread-4] INFO  org.apache.spark.util.Utils - Fetching spark://spark-master:7081/jars/com.vladsch.flexmark_flexmark-util-sequence-0.61.34.jar to /tmp/spark-55f4f8c7-2dcc-4759-bdff-34d5ce613e83/userFiles-a2ea4a13-9974-47e4-92e6-bb48b6c59fc7/fetchFileTemp6451857856098825217.tmp
# 12:47:42.331 [Thread-4] INFO  org.apache.spark.util.Utils - /tmp/spark-55f4f8c7-2dcc-4759-bdff-34d5ce613e83/userFiles-a2ea4a13-9974-47e4-92e6-bb48b6c59fc7/fetchFileTemp6451857856098825217.tmp has been previously copied to /tmp/spark-55f4f8c7-2dcc-4759-bdff-34d5ce613e83/userFiles-a2ea4a13-9974-47e4-92e6-bb48b6c59fc7/com.vladsch.flexmark_flexmark-util-sequence-0.61.34.jar
# 12:47:42.333 [Thread-4] INFO  org.apache.spark.executor.Executor - Adding file:/tmp/spark-55f4f8c7-2dcc-4759-bdff-34d5ce613e83/userFiles-a2ea4a13-9974-47e4-92e6-bb48b6c59fc7/com.vladsch.flexmark_flexmark-util-sequence-0.61.34.jar to class loader default
# 12:47:42.333 [Thread-4] INFO  org.apache.spark.executor.Executor - Fetching spark://spark-master:7081/jars/io.perfmark_perfmark-api-0.26.0.jar with timestamp 1757854055526
# 12:47:42.333 [Thread-4] INFO  org.apache.spark.util.Utils - Fetching spark://spark-master:7081/jars/io.perfmark_perfmark-api-0.26.0.jar to /tmp/spark-55f4f8c7-2dcc-4759-bdff-34d5ce613e83/userFiles-a2ea4a13-9974-47e4-92e6-bb48b6c59fc7/fetchFileTemp1521181816957353122.tmp
# 12:47:42.334 [Thread-4] INFO  org.apache.spark.util.Utils - /tmp/spark-55f4f8c7-2dcc-4759-bdff-34d5ce613e83/userFiles-a2ea4a13-9974-47e4-92e6-bb48b6c59fc7/fetchFileTemp1521181816957353122.tmp has been previously copied to /tmp/spark-55f4f8c7-2dcc-4759-bdff-34d5ce613e83/userFiles-a2ea4a13-9974-47e4-92e6-bb48b6c59fc7/io.perfmark_perfmark-api-0.26.0.jar
# 12:47:42.335 [Thread-4] INFO  org.apache.spark.executor.Executor - Adding file:/tmp/spark-55f4f8c7-2dcc-4759-bdff-34d5ce613e83/userFiles-a2ea4a13-9974-47e4-92e6-bb48b6c59fc7/io.perfmark_perfmark-api-0.26.0.jar to class loader default
# 12:47:42.335 [Thread-4] INFO  org.apache.spark.executor.Executor - Fetching spark://spark-master:7081/jars/io.grpc_grpc-api-1.53.0.jar with timestamp 1757854055526
# 12:47:42.336 [Thread-4] INFO  org.apache.spark.util.Utils - Fetching spark://spark-master:7081/jars/io.grpc_grpc-api-1.53.0.jar to /tmp/spark-55f4f8c7-2dcc-4759-bdff-34d5ce613e83/userFiles-a2ea4a13-9974-47e4-92e6-bb48b6c59fc7/fetchFileTemp11304755056174202793.tmp
# 12:47:42.337 [Thread-4] INFO  org.apache.spark.util.Utils - /tmp/spark-55f4f8c7-2dcc-4759-bdff-34d5ce613e83/userFiles-a2ea4a13-9974-47e4-92e6-bb48b6c59fc7/fetchFileTemp11304755056174202793.tmp has been previously copied to /tmp/spark-55f4f8c7-2dcc-4759-bdff-34d5ce613e83/userFiles-a2ea4a13-9974-47e4-92e6-bb48b6c59fc7/io.grpc_grpc-api-1.53.0.jar
# 12:47:42.339 [Thread-4] INFO  org.apache.spark.executor.Executor - Adding file:/tmp/spark-55f4f8c7-2dcc-4759-bdff-34d5ce613e83/userFiles-a2ea4a13-9974-47e4-92e6-bb48b6c59fc7/io.grpc_grpc-api-1.53.0.jar to class loader default
# 12:47:42.339 [Thread-4] INFO  org.apache.spark.executor.Executor - Fetching spark://spark-master:7081/jars/com.johnsnowlabs.nlp_jsl-openvino-cpu_2.12-0.2.0.jar with timestamp 1757854055526
# 12:47:42.339 [Thread-4] INFO  org.apache.spark.util.Utils - Fetching spark://spark-master:7081/jars/com.johnsnowlabs.nlp_jsl-openvino-cpu_2.12-0.2.0.jar to /tmp/spark-55f4f8c7-2dcc-4759-bdff-34d5ce613e83/userFiles-a2ea4a13-9974-47e4-92e6-bb48b6c59fc7/fetchFileTemp7473793659076593881.tmp
# 12:47:42.502 [Thread-4] INFO  org.apache.spark.util.Utils - /tmp/spark-55f4f8c7-2dcc-4759-bdff-34d5ce613e83/userFiles-a2ea4a13-9974-47e4-92e6-bb48b6c59fc7/fetchFileTemp7473793659076593881.tmp has been previously copied to /tmp/spark-55f4f8c7-2dcc-4759-bdff-34d5ce613e83/userFiles-a2ea4a13-9974-47e4-92e6-bb48b6c59fc7/com.johnsnowlabs.nlp_jsl-openvino-cpu_2.12-0.2.0.jar
# 12:47:42.507 [Thread-4] INFO  org.apache.spark.executor.Executor - Adding file:/tmp/spark-55f4f8c7-2dcc-4759-bdff-34d5ce613e83/userFiles-a2ea4a13-9974-47e4-92e6-bb48b6c59fc7/com.johnsnowlabs.nlp_jsl-openvino-cpu_2.12-0.2.0.jar to class loader default
# 12:47:42.507 [Thread-4] INFO  org.apache.spark.executor.Executor - Fetching spark://spark-master:7081/jars/com.vladsch.flexmark_flexmark-ext-emoji-0.61.34.jar with timestamp 1757854055526
# 12:47:42.508 [Thread-4] INFO  org.apache.spark.util.Utils - Fetching spark://spark-master:7081/jars/com.vladsch.flexmark_flexmark-ext-emoji-0.61.34.jar to /tmp/spark-55f4f8c7-2dcc-4759-bdff-34d5ce613e83/userFiles-a2ea4a13-9974-47e4-92e6-bb48b6c59fc7/fetchFileTemp6652128778302658079.tmp
# 12:47:42.509 [Thread-4] INFO  org.apache.spark.util.Utils - /tmp/spark-55f4f8c7-2dcc-4759-bdff-34d5ce613e83/userFiles-a2ea4a13-9974-47e4-92e6-bb48b6c59fc7/fetchFileTemp6652128778302658079.tmp has been previously copied to /tmp/spark-55f4f8c7-2dcc-4759-bdff-34d5ce613e83/userFiles-a2ea4a13-9974-47e4-92e6-bb48b6c59fc7/com.vladsch.flexmark_flexmark-ext-emoji-0.61.34.jar
# 12:47:42.510 [Thread-4] INFO  org.apache.spark.executor.Executor - Adding file:/tmp/spark-55f4f8c7-2dcc-4759-bdff-34d5ce613e83/userFiles-a2ea4a13-9974-47e4-92e6-bb48b6c59fc7/com.vladsch.flexmark_flexmark-ext-emoji-0.61.34.jar to class loader default
# 12:47:42.511 [Thread-4] INFO  org.apache.spark.executor.Executor - Fetching spark://spark-master:7081/jars/org.apache.xmlbeans_xmlbeans-3.1.0.jar with timestamp 1757854055526
# 12:47:42.511 [Thread-4] INFO  org.apache.spark.util.Utils - Fetching spark://spark-master:7081/jars/org.apache.xmlbeans_xmlbeans-3.1.0.jar to /tmp/spark-55f4f8c7-2dcc-4759-bdff-34d5ce613e83/userFiles-a2ea4a13-9974-47e4-92e6-bb48b6c59fc7/fetchFileTemp7350500103173735628.tmp
# 12:47:42.517 [Thread-4] INFO  org.apache.spark.util.Utils - /tmp/spark-55f4f8c7-2dcc-4759-bdff-34d5ce613e83/userFiles-a2ea4a13-9974-47e4-92e6-bb48b6c59fc7/fetchFileTemp7350500103173735628.tmp has been previously copied to /tmp/spark-55f4f8c7-2dcc-4759-bdff-34d5ce613e83/userFiles-a2ea4a13-9974-47e4-92e6-bb48b6c59fc7/org.apache.xmlbeans_xmlbeans-3.1.0.jar
# 12:47:42.519 [Thread-4] INFO  org.apache.spark.executor.Executor - Adding file:/tmp/spark-55f4f8c7-2dcc-4759-bdff-34d5ce613e83/userFiles-a2ea4a13-9974-47e4-92e6-bb48b6c59fc7/org.apache.xmlbeans_xmlbeans-3.1.0.jar to class loader default
# 12:47:42.544 [Thread-4] WARN  org.apache.spark.util.Utils - Service 'org.apache.spark.network.netty.NettyBlockTransferService' could not bind on port 7079. Attempting port 7080.
# 12:47:42.546 [Thread-4] WARN  org.apache.spark.util.Utils - Service 'org.apache.spark.network.netty.NettyBlockTransferService' could not bind on port 7080. Attempting port 7081.
# 12:47:42.548 [Thread-4] WARN  org.apache.spark.util.Utils - Service 'org.apache.spark.network.netty.NettyBlockTransferService' could not bind on port 7081. Attempting port 7082.
# 12:47:42.549 [Thread-4] INFO  org.apache.spark.util.Utils - Successfully started service 'org.apache.spark.network.netty.NettyBlockTransferService' on port 7082.
# 12:47:42.549 [Thread-4] INFO  org.apache.spark.network.netty.NettyBlockTransferService - Server created on spark-master 0.0.0.0:7082
# 12:47:42.551 [Thread-4] INFO  org.apache.spark.storage.BlockManager - Using org.apache.spark.storage.RandomBlockReplicationPolicy for block replication policy
# 12:47:42.551 [Thread-4] INFO  org.apache.spark.storage.BlockManager - external shuffle service port = 7337
# 12:47:42.562 [Thread-4] INFO  org.apache.spark.storage.BlockManagerMaster - Registering BlockManager BlockManagerId(driver, spark-master, 7082, None)
# 12:47:42.566 [dispatcher-BlockManagerMaster] INFO  org.apache.spark.storage.BlockManagerMasterEndpoint - Registering block manager spark-master:7082 with 9.4 GiB RAM, BlockManagerId(driver, spark-master, 7082, None)
# 12:47:42.569 [Thread-4] INFO  org.apache.spark.storage.BlockManagerMaster - Registered BlockManager BlockManagerId(driver, spark-master, 7082, None)
# 12:47:42.570 [Thread-4] INFO  org.apache.spark.storage.BlockManager - Initialized BlockManager: BlockManagerId(driver, spark-master, 7082, None)
# 12:47:42.761 [Thread-4] INFO  org.apache.spark.deploy.history.RollingEventLogFilesWriter - Logging events to file:/opt/spark/events/eventlog_v2_local-1757854057899/events_1_local-1757854057899.zstd
# 12:47:42.909 [Thread-4] INFO  org.sparkproject.jetty.server.handler.ContextHandler - Stopped o.s.j.s.ServletContextHandler@21e55679{/,null,STOPPED,@Spark}
# 12:47:42.911 [Thread-4] INFO  org.sparkproject.jetty.server.handler.ContextHandler - Started o.s.j.s.ServletContextHandler@1d4b34fa{/jobs,null,AVAILABLE,@Spark}
# 12:47:42.911 [Thread-4] INFO  org.sparkproject.jetty.server.handler.ContextHandler - Started o.s.j.s.ServletContextHandler@612a69b6{/jobs/json,null,AVAILABLE,@Spark}
# 12:47:42.912 [Thread-4] INFO  org.sparkproject.jetty.server.handler.ContextHandler - Started o.s.j.s.ServletContextHandler@4e7f9d65{/jobs/job,null,AVAILABLE,@Spark}
# 12:47:42.913 [Thread-4] INFO  org.sparkproject.jetty.server.handler.ContextHandler - Started o.s.j.s.ServletContextHandler@4abd8066{/jobs/job/json,null,AVAILABLE,@Spark}
# 12:47:42.913 [Thread-4] INFO  org.sparkproject.jetty.server.handler.ContextHandler - Started o.s.j.s.ServletContextHandler@55783e51{/stages,null,AVAILABLE,@Spark}
# 12:47:42.913 [Thread-4] INFO  org.sparkproject.jetty.server.handler.ContextHandler - Started o.s.j.s.ServletContextHandler@7e33448c{/stages/json,null,AVAILABLE,@Spark}
# 12:47:42.914 [Thread-4] INFO  org.sparkproject.jetty.server.handler.ContextHandler - Started o.s.j.s.ServletContextHandler@7e5ab27d{/stages/stage,null,AVAILABLE,@Spark}
# 12:47:42.915 [Thread-4] INFO  org.sparkproject.jetty.server.handler.ContextHandler - Started o.s.j.s.ServletContextHandler@3369499{/stages/stage/json,null,AVAILABLE,@Spark}
# 12:47:42.917 [Thread-4] INFO  org.sparkproject.jetty.server.handler.ContextHandler - Started o.s.j.s.ServletContextHandler@608190c6{/stages/pool,null,AVAILABLE,@Spark}
# 12:47:42.918 [Thread-4] INFO  org.sparkproject.jetty.server.handler.ContextHandler - Started o.s.j.s.ServletContextHandler@1fc08646{/stages/pool/json,null,AVAILABLE,@Spark}
# 12:47:42.918 [Thread-4] INFO  org.sparkproject.jetty.server.handler.ContextHandler - Started o.s.j.s.ServletContextHandler@20cf7ea3{/storage,null,AVAILABLE,@Spark}
# 12:47:42.919 [Thread-4] INFO  org.sparkproject.jetty.server.handler.ContextHandler - Started o.s.j.s.ServletContextHandler@392d06a8{/storage/json,null,AVAILABLE,@Spark}
# 12:47:42.919 [Thread-4] INFO  org.sparkproject.jetty.server.handler.ContextHandler - Started o.s.j.s.ServletContextHandler@800292d{/storage/rdd,null,AVAILABLE,@Spark}
# 12:47:42.920 [Thread-4] INFO  org.sparkproject.jetty.server.handler.ContextHandler - Started o.s.j.s.ServletContextHandler@59bdc59b{/storage/rdd/json,null,AVAILABLE,@Spark}
# 12:47:42.920 [Thread-4] INFO  org.sparkproject.jetty.server.handler.ContextHandler - Started o.s.j.s.ServletContextHandler@8380434{/environment,null,AVAILABLE,@Spark}
# 12:47:42.921 [Thread-4] INFO  org.sparkproject.jetty.server.handler.ContextHandler - Started o.s.j.s.ServletContextHandler@1395788a{/environment/json,null,AVAILABLE,@Spark}
# 12:47:42.921 [Thread-4] INFO  org.sparkproject.jetty.server.handler.ContextHandler - Started o.s.j.s.ServletContextHandler@1a9e72e2{/executors,null,AVAILABLE,@Spark}
# 12:47:42.922 [Thread-4] INFO  org.sparkproject.jetty.server.handler.ContextHandler - Started o.s.j.s.ServletContextHandler@19fb8b9b{/executors/json,null,AVAILABLE,@Spark}
# 12:47:42.924 [Thread-4] INFO  org.sparkproject.jetty.server.handler.ContextHandler - Started o.s.j.s.ServletContextHandler@5c511ea4{/executors/threadDump,null,AVAILABLE,@Spark}
# 12:47:42.926 [Thread-4] INFO  org.sparkproject.jetty.server.handler.ContextHandler - Started o.s.j.s.ServletContextHandler@2fa7709b{/executors/threadDump/json,null,AVAILABLE,@Spark}
# 12:47:42.927 [Thread-4] INFO  org.sparkproject.jetty.server.handler.ContextHandler - Started o.s.j.s.ServletContextHandler@45c433a2{/executors/heapHistogram,null,AVAILABLE,@Spark}
# 12:47:42.927 [Thread-4] INFO  org.sparkproject.jetty.server.handler.ContextHandler - Started o.s.j.s.ServletContextHandler@17b8ec12{/executors/heapHistogram/json,null,AVAILABLE,@Spark}
# 12:47:42.939 [Thread-4] INFO  org.sparkproject.jetty.server.handler.ContextHandler - Started o.s.j.s.ServletContextHandler@47dd375d{/static,null,AVAILABLE,@Spark}
# 12:47:42.940 [Thread-4] INFO  org.sparkproject.jetty.server.handler.ContextHandler - Started o.s.j.s.ServletContextHandler@546f0002{/,null,AVAILABLE,@Spark}
# 12:47:42.943 [Thread-4] INFO  org.sparkproject.jetty.server.handler.ContextHandler - Started o.s.j.s.ServletContextHandler@711ab5b7{/api,null,AVAILABLE,@Spark}
# 12:47:42.944 [Thread-4] INFO  org.sparkproject.jetty.server.handler.ContextHandler - Started o.s.j.s.ServletContextHandler@6e26dcc0{/jobs/job/kill,null,AVAILABLE,@Spark}
# 12:47:42.945 [Thread-4] INFO  org.sparkproject.jetty.server.handler.ContextHandler - Started o.s.j.s.ServletContextHandler@7251b018{/stages/stage/kill,null,AVAILABLE,@Spark}
# 12:47:42.948 [Thread-4] INFO  org.sparkproject.jetty.server.handler.ContextHandler - Started o.s.j.s.ServletContextHandler@27d84d4c{/metrics/json,null,AVAILABLE,@Spark}

# %%
pipeline = PretrainedPipeline('recognize_entities_dl', 'en')
# Out:
# recognize_entities_dl download started this may take some time.
# 12:48:24.434 [Thread-4] INFO  org.apache.spark.sql.internal.SharedState - Setting hive.metastore.warehouse.dir ('null') to the value of spark.sql.warehouse.dir.
# 12:48:24.436 [Thread-4] INFO  org.apache.spark.sql.internal.SharedState - Warehouse path is 'file:/opt/spark/notebook/spark-warehouse'.
# 12:48:24.453 [Thread-4] INFO  org.sparkproject.jetty.server.handler.ContextHandler - Started o.s.j.s.ServletContextHandler@34052730{/SQL,null,AVAILABLE,@Spark}
# 12:48:24.453 [Thread-4] INFO  org.sparkproject.jetty.server.handler.ContextHandler - Started o.s.j.s.ServletContextHandler@2d689adc{/SQL/json,null,AVAILABLE,@Spark}
# 12:48:24.454 [Thread-4] INFO  org.sparkproject.jetty.server.handler.ContextHandler - Started o.s.j.s.ServletContextHandler@77433f2f{/SQL/execution,null,AVAILABLE,@Spark}
# 12:48:24.454 [Thread-4] INFO  org.sparkproject.jetty.server.handler.ContextHandler - Started o.s.j.s.ServletContextHandler@35984578{/SQL/execution/json,null,AVAILABLE,@Spark}
# 12:48:24.456 [Thread-4] INFO  org.sparkproject.jetty.server.handler.ContextHandler - Started o.s.j.s.ServletContextHandler@24a5248{/static/sql,null,AVAILABLE,@Spark}
# 12:48:25.044 [Thread-4] INFO  Credentials - Connecting to AWS with Anonymous AWS Credentials...
# Approx size to download 159 MB
# [ | ]12:48:34.407 [Thread-4] WARN  com.amazonaws.ShadedByJSLservices.s3.internal.S3AbortableInputStream - Not all bytes were read from the S3ObjectInputStream, aborting HTTP connection. This is likely an error and may result in sub-optimal behavior. Request only the bytes you need via a ranged GET or drain the input stream after use.
# 12:48:34.824 [scala-execution-context-global-603] WARN  com.amazonaws.ShadedByJSLservices.s3.internal.S3AbortableInputStream - Not all bytes were read from the S3ObjectInputStream, aborting HTTP connection. This is likely an error and may result in sub-optimal behavior. Request only the bytes you need via a ranged GET or drain the input stream after use.
# 12:48:34.830 [scala-execution-context-global-603] INFO  class com.johnsnowlabs.nlp.pretrained.S3ResourceDownloader - In S3ResourceDownloader.download: public/models/recognize_entities_dl_en_4.4.2_3.4_1685041151703.zip
# recognize_entities_dl download started this may take some time.
# Approximate size to download 159 MB
# 12:48:35.463 [scala-execution-context-global-603] INFO  class com.johnsnowlabs.nlp.pretrained.S3ResourceDownloader - Resource found in S3
# 12:48:35.464 [scala-execution-context-global-603] INFO  class com.johnsnowlabs.nlp.pretrained.S3ResourceDownloader - Before cachePath.toString: file:/root/cache_pretrained
# 12:48:35.464 [scala-execution-context-global-603] INFO  class com.johnsnowlabs.nlp.pretrained.S3ResourceDownloader - In S3ResourceDownloader before downloadAndUnzipFile
# [ — ]Download done! Loading the resource.
# 12:49:00.451 [Thread-4] INFO  org.apache.spark.storage.memory.MemoryStore - Block broadcast_0 stored as values in memory (estimated size 225.4 KiB, free 9.4 GiB)
# 12:49:00.921 [Thread-4] INFO  org.apache.spark.storage.memory.MemoryStore - Block broadcast_0_piece0 stored as bytes in memory (estimated size 44.6 KiB, free 9.4 GiB)
# 12:49:00.925 [dispatcher-BlockManagerMaster] INFO  org.apache.spark.storage.BlockManagerInfo - Added broadcast_0_piece0 in memory on spark-master:7082 (size: 44.6 KiB, free: 9.4 GiB)
# 12:49:00.930 [Thread-4] INFO  org.apache.spark.SparkContext - Created broadcast 0 from textFile at ReadWrite.scala:587
# 12:49:01.204 [Thread-4] INFO  org.apache.hadoop.mapred.FileInputFormat - Total input files to process : 1
# 12:49:01.287 [Thread-4] INFO  org.apache.spark.SparkContext - Starting job: first at ReadWrite.scala:587
# 12:49:01.307 [dag-scheduler-event-loop] INFO  org.apache.spark.scheduler.DAGScheduler - Got job 0 (first at ReadWrite.scala:587) with 1 output partitions
# 12:49:01.308 [dag-scheduler-event-loop] INFO  org.apache.spark.scheduler.DAGScheduler - Final stage: ResultStage 0 (first at ReadWrite.scala:587)
# 12:49:01.308 [dag-scheduler-event-loop] INFO  org.apache.spark.scheduler.DAGScheduler - Parents of final stage: List()
# 12:49:01.312 [dag-scheduler-event-loop] INFO  org.apache.spark.scheduler.DAGScheduler - Missing parents: List()
# 12:49:01.317 [dag-scheduler-event-loop] INFO  org.apache.spark.scheduler.DAGScheduler - Submitting ResultStage 0 (file:/root/cache_pretrained/recognize_entities_dl_en_4.4.2_3.4_1685041151703/metadata MapPartitionsRDD[1] at textFile at ReadWrite.scala:587), which has no missing parents
# 12:49:01.382 [dag-scheduler-event-loop] INFO  org.apache.spark.storage.memory.MemoryStore - Block broadcast_1 stored as values in memory (estimated size 5.0 KiB, free 9.4 GiB)
# 12:49:01.387 [dag-scheduler-event-loop] INFO  org.apache.spark.storage.memory.MemoryStore - Block broadcast_1_piece0 stored as bytes in memory (estimated size 2.9 KiB, free 9.4 GiB)
# 12:49:01.388 [dispatcher-BlockManagerMaster] INFO  org.apache.spark.storage.BlockManagerInfo - Added broadcast_1_piece0 in memory on spark-master:7082 (size: 2.9 KiB, free: 9.4 GiB)
# 12:49:01.391 [dag-scheduler-event-loop] INFO  org.apache.spark.SparkContext - Created broadcast 1 from broadcast at DAGScheduler.scala:1585
# 12:49:01.422 [dag-scheduler-event-loop] INFO  org.apache.spark.scheduler.DAGScheduler - Submitting 1 missing tasks from ResultStage 0 (file:/root/cache_pretrained/recognize_entities_dl_en_4.4.2_3.4_1685041151703/metadata MapPartitionsRDD[1] at textFile at ReadWrite.scala:587) (first 15 tasks are for partitions Vector(0))
# 12:49:01.427 [dag-scheduler-event-loop] INFO  org.apache.spark.scheduler.TaskSchedulerImpl - Adding task set 0.0 with 1 tasks resource profile 0
# 12:49:01.459 [dag-scheduler-event-loop] INFO  org.apache.spark.scheduler.FairSchedulableBuilder - Added task set TaskSet_0.0 tasks to pool default
# 12:49:01.516 [dispatcher-event-loop-5] INFO  org.apache.spark.scheduler.TaskSetManager - Starting task 0.0 in stage 0.0 (TID 0) (0ea22e89e591, executor driver, partition 0, PROCESS_LOCAL, 37264 bytes)
# 12:49:01.529 [Executor task launch worker for task 0.0 in stage 0.0 (TID 0)] INFO  org.apache.spark.executor.Executor - Running task 0.0 in stage 0.0 (TID 0)
# 12:49:01.592 [Executor task launch worker for task 0.0 in stage 0.0 (TID 0)] INFO  org.apache.spark.rdd.HadoopRDD - Input split: file:/root/cache_pretrained/recognize_entities_dl_en_4.4.2_3.4_1685041151703/metadata/part-00000:0+349
# 12:49:01.631 [Executor task launch worker for task 0.0 in stage 0.0 (TID 0)] INFO  org.apache.spark.executor.Executor - Finished task 0.0 in stage 0.0 (TID 0). 1291 bytes result sent to driver
# 12:49:01.646 [task-result-getter-0] INFO  org.apache.spark.scheduler.TaskSetManager - Finished task 0.0 in stage 0.0 (TID 0) in 158 ms on 0ea22e89e591 (executor driver) (1/1)
# 12:49:01.647 [task-result-getter-0] INFO  org.apache.spark.scheduler.TaskSchedulerImpl - Removed TaskSet 0.0, whose tasks have all completed, from pool default
# 12:49:01.653 [dag-scheduler-event-loop] INFO  org.apache.spark.scheduler.DAGScheduler - ResultStage 0 (first at ReadWrite.scala:587) finished in 0.309 s
# 12:49:01.655 [dag-scheduler-event-loop] INFO  org.apache.spark.scheduler.DAGScheduler - Job 0 is finished. Cancelling potential speculative or zombie tasks for this job
# 12:49:01.656 [dag-scheduler-event-loop] INFO  org.apache.spark.scheduler.TaskSchedulerImpl - Killing all running tasks in stage 0: Stage finished
# 12:49:01.683 [Thread-4] INFO  org.apache.spark.scheduler.DAGScheduler - Job 0 finished: first at ReadWrite.scala:587, took 0.396199 s
# 12:49:01.704 [Thread-4] INFO  org.apache.spark.storage.memory.MemoryStore - Block broadcast_2 stored as values in memory (estimated size 225.4 KiB, free 9.4 GiB)
# 12:49:01.719 [Thread-4] INFO  org.apache.spark.storage.memory.MemoryStore - Block broadcast_2_piece0 stored as bytes in memory (estimated size 44.6 KiB, free 9.4 GiB)
# 12:49:01.720 [dispatcher-BlockManagerMaster] INFO  org.apache.spark.storage.BlockManagerInfo - Added broadcast_2_piece0 in memory on spark-master:7082 (size: 44.6 KiB, free: 9.4 GiB)
# 12:49:01.721 [Thread-4] INFO  org.apache.spark.SparkContext - Created broadcast 2 from textFile at ReadWrite.scala:587
# [ \ ]12:49:01.760 [Thread-4] INFO  org.apache.hadoop.mapred.FileInputFormat - Total input files to process : 1
# 12:49:01.777 [Thread-4] INFO  org.apache.spark.SparkContext - Starting job: first at ReadWrite.scala:587
# 12:49:01.778 [dag-scheduler-event-loop] INFO  org.apache.spark.scheduler.DAGScheduler - Got job 1 (first at ReadWrite.scala:587) with 1 output partitions
# 12:49:01.778 [dag-scheduler-event-loop] INFO  org.apache.spark.scheduler.DAGScheduler - Final stage: ResultStage 1 (first at ReadWrite.scala:587)
# 12:49:01.778 [dag-scheduler-event-loop] INFO  org.apache.spark.scheduler.DAGScheduler - Parents of final stage: List()
# 12:49:01.778 [dag-scheduler-event-loop] INFO  org.apache.spark.scheduler.DAGScheduler - Missing parents: List()
# 12:49:01.779 [dag-scheduler-event-loop] INFO  org.apache.spark.scheduler.DAGScheduler - Submitting ResultStage 1 (file:/root/cache_pretrained/recognize_entities_dl_en_4.4.2_3.4_1685041151703/stages/0_document_1c58bc1aca5d/metadata MapPartitionsRDD[3] at textFile at ReadWrite.scala:587), which has no missing parents
# 12:49:01.781 [dag-scheduler-event-loop] INFO  org.apache.spark.storage.memory.MemoryStore - Block broadcast_3 stored as values in memory (estimated size 5.1 KiB, free 9.4 GiB)
# 12:49:01.783 [dag-scheduler-event-loop] INFO  org.apache.spark.storage.memory.MemoryStore - Block broadcast_3_piece0 stored as bytes in memory (estimated size 3.0 KiB, free 9.4 GiB)
# 12:49:01.783 [dispatcher-BlockManagerMaster] INFO  org.apache.spark.storage.BlockManagerInfo - Added broadcast_3_piece0 in memory on spark-master:7082 (size: 3.0 KiB, free: 9.4 GiB)
# 12:49:01.784 [dag-scheduler-event-loop] INFO  org.apache.spark.SparkContext - Created broadcast 3 from broadcast at DAGScheduler.scala:1585
# 12:49:01.784 [dag-scheduler-event-loop] INFO  org.apache.spark.scheduler.DAGScheduler - Submitting 1 missing tasks from ResultStage 1 (file:/root/cache_pretrained/recognize_entities_dl_en_4.4.2_3.4_1685041151703/stages/0_document_1c58bc1aca5d/metadata MapPartitionsRDD[3] at textFile at ReadWrite.scala:587) (first 15 tasks are for partitions Vector(0))
# 12:49:01.784 [dag-scheduler-event-loop] INFO  org.apache.spark.scheduler.TaskSchedulerImpl - Adding task set 1.0 with 1 tasks resource profile 0
# 12:49:01.785 [dag-scheduler-event-loop] INFO  org.apache.spark.scheduler.FairSchedulableBuilder - Added task set TaskSet_1.0 tasks to pool default
# 12:49:01.787 [dispatcher-event-loop-1] INFO  org.apache.spark.scheduler.TaskSetManager - Starting task 0.0 in stage 1.0 (TID 1) (0ea22e89e591, executor driver, partition 0, PROCESS_LOCAL, 37295 bytes)
# 12:49:01.787 [Executor task launch worker for task 0.0 in stage 1.0 (TID 1)] INFO  org.apache.spark.executor.Executor - Running task 0.0 in stage 1.0 (TID 1)
# 12:49:01.793 [Executor task launch worker for task 0.0 in stage 1.0 (TID 1)] INFO  org.apache.spark.rdd.HadoopRDD - Input split: file:/root/cache_pretrained/recognize_entities_dl_en_4.4.2_3.4_1685041151703/stages/0_document_1c58bc1aca5d/metadata/part-00000:0+252
# 12:49:01.799 [Executor task launch worker for task 0.0 in stage 1.0 (TID 1)] INFO  org.apache.spark.executor.Executor - Finished task 0.0 in stage 1.0 (TID 1). 1151 bytes result sent to driver
# 12:49:01.800 [task-result-getter-1] INFO  org.apache.spark.scheduler.TaskSetManager - Finished task 0.0 in stage 1.0 (TID 1) in 15 ms on 0ea22e89e591 (executor driver) (1/1)
# 12:49:01.800 [task-result-getter-1] INFO  org.apache.spark.scheduler.TaskSchedulerImpl - Removed TaskSet 1.0, whose tasks have all completed, from pool default
# 12:49:01.801 [dag-scheduler-event-loop] INFO  org.apache.spark.scheduler.DAGScheduler - ResultStage 1 (first at ReadWrite.scala:587) finished in 0.022 s
# 12:49:01.802 [dag-scheduler-event-loop] INFO  org.apache.spark.scheduler.DAGScheduler - Job 1 is finished. Cancelling potential speculative or zombie tasks for this job
# 12:49:01.802 [dag-scheduler-event-loop] INFO  org.apache.spark.scheduler.TaskSchedulerImpl - Killing all running tasks in stage 1: Stage finished
# 12:49:01.802 [Thread-4] INFO  org.apache.spark.scheduler.DAGScheduler - Job 1 finished: first at ReadWrite.scala:587, took 0.025164 s
# 12:49:01.819 [Thread-4] INFO  org.apache.spark.storage.memory.MemoryStore - Block broadcast_4 stored as values in memory (estimated size 225.4 KiB, free 9.4 GiB)
# 12:49:01.830 [Thread-4] INFO  org.apache.spark.storage.memory.MemoryStore - Block broadcast_4_piece0 stored as bytes in memory (estimated size 44.6 KiB, free 9.4 GiB)
# 12:49:01.830 [dispatcher-BlockManagerMaster] INFO  org.apache.spark.storage.BlockManagerInfo - Added broadcast_4_piece0 in memory on spark-master:7082 (size: 44.6 KiB, free: 9.4 GiB)
# 12:49:01.831 [Thread-4] INFO  org.apache.spark.SparkContext - Created broadcast 4 from textFile at ReadWrite.scala:587
# 12:49:01.854 [Thread-4] INFO  org.apache.hadoop.mapred.FileInputFormat - Total input files to process : 1
# 12:49:01.865 [Thread-4] INFO  org.apache.spark.SparkContext - Starting job: first at ReadWrite.scala:587
# 12:49:01.869 [dag-scheduler-event-loop] INFO  org.apache.spark.scheduler.DAGScheduler - Got job 2 (first at ReadWrite.scala:587) with 1 output partitions
# 12:49:01.869 [dag-scheduler-event-loop] INFO  org.apache.spark.scheduler.DAGScheduler - Final stage: ResultStage 2 (first at ReadWrite.scala:587)
# 12:49:01.869 [dag-scheduler-event-loop] INFO  org.apache.spark.scheduler.DAGScheduler - Parents of final stage: List()
# 12:49:01.870 [dag-scheduler-event-loop] INFO  org.apache.spark.scheduler.DAGScheduler - Missing parents: List()
# 12:49:01.871 [dag-scheduler-event-loop] INFO  org.apache.spark.scheduler.DAGScheduler - Submitting ResultStage 2 (file:/root/cache_pretrained/recognize_entities_dl_en_4.4.2_3.4_1685041151703/stages/0_document_1c58bc1aca5d/metadata MapPartitionsRDD[5] at textFile at ReadWrite.scala:587), which has no missing parents
# 12:49:01.876 [dag-scheduler-event-loop] INFO  org.apache.spark.storage.memory.MemoryStore - Block broadcast_5 stored as values in memory (estimated size 5.1 KiB, free 9.4 GiB)
# 12:49:01.886 [dag-scheduler-event-loop] INFO  org.apache.spark.storage.memory.MemoryStore - Block broadcast_5_piece0 stored as bytes in memory (estimated size 3.0 KiB, free 9.4 GiB)
# 12:49:01.887 [dispatcher-BlockManagerMaster] INFO  org.apache.spark.storage.BlockManagerInfo - Added broadcast_5_piece0 in memory on spark-master:7082 (size: 3.0 KiB, free: 9.4 GiB)
# 12:49:01.887 [dag-scheduler-event-loop] INFO  org.apache.spark.SparkContext - Created broadcast 5 from broadcast at DAGScheduler.scala:1585
# 12:49:01.889 [dag-scheduler-event-loop] INFO  org.apache.spark.scheduler.DAGScheduler - Submitting 1 missing tasks from ResultStage 2 (file:/root/cache_pretrained/recognize_entities_dl_en_4.4.2_3.4_1685041151703/stages/0_document_1c58bc1aca5d/metadata MapPartitionsRDD[5] at textFile at ReadWrite.scala:587) (first 15 tasks are for partitions Vector(0))
# 12:49:01.889 [dag-scheduler-event-loop] INFO  org.apache.spark.scheduler.TaskSchedulerImpl - Adding task set 2.0 with 1 tasks resource profile 0
# 12:49:01.891 [dag-scheduler-event-loop] INFO  org.apache.spark.scheduler.FairSchedulableBuilder - Added task set TaskSet_2.0 tasks to pool default
# 12:49:01.893 [dispatcher-event-loop-5] INFO  org.apache.spark.scheduler.TaskSetManager - Starting task 0.0 in stage 2.0 (TID 2) (0ea22e89e591, executor driver, partition 0, PROCESS_LOCAL, 37295 bytes)
# 12:49:01.896 [Executor task launch worker for task 0.0 in stage 2.0 (TID 2)] INFO  org.apache.spark.executor.Executor - Running task 0.0 in stage 2.0 (TID 2)
# 12:49:01.904 [Executor task launch worker for task 0.0 in stage 2.0 (TID 2)] INFO  org.apache.spark.rdd.HadoopRDD - Input split: file:/root/cache_pretrained/recognize_entities_dl_en_4.4.2_3.4_1685041151703/stages/0_document_1c58bc1aca5d/metadata/part-00000:0+252
# 12:49:01.908 [Executor task launch worker for task 0.0 in stage 2.0 (TID 2)] INFO  org.apache.spark.executor.Executor - Finished task 0.0 in stage 2.0 (TID 2). 1151 bytes result sent to driver
# 12:49:01.909 [task-result-getter-2] INFO  org.apache.spark.scheduler.TaskSetManager - Finished task 0.0 in stage 2.0 (TID 2) in 17 ms on 0ea22e89e591 (executor driver) (1/1)
# 12:49:01.909 [task-result-getter-2] INFO  org.apache.spark.scheduler.TaskSchedulerImpl - Removed TaskSet 2.0, whose tasks have all completed, from pool default
# 12:49:01.910 [dag-scheduler-event-loop] INFO  org.apache.spark.scheduler.DAGScheduler - ResultStage 2 (first at ReadWrite.scala:587) finished in 0.038 s
# 12:49:01.910 [dag-scheduler-event-loop] INFO  org.apache.spark.scheduler.DAGScheduler - Job 2 is finished. Cancelling potential speculative or zombie tasks for this job
# 12:49:01.910 [dag-scheduler-event-loop] INFO  org.apache.spark.scheduler.TaskSchedulerImpl - Killing all running tasks in stage 2: Stage finished
# 12:49:01.910 [Thread-4] INFO  org.apache.spark.scheduler.DAGScheduler - Job 2 finished: first at ReadWrite.scala:587, took 0.044767 s
# 12:49:01.930 [Thread-4] INFO  org.apache.spark.storage.memory.MemoryStore - Block broadcast_6 stored as values in memory (estimated size 225.4 KiB, free 9.4 GiB)
# 12:49:01.943 [Thread-4] INFO  org.apache.spark.storage.memory.MemoryStore - Block broadcast_6_piece0 stored as bytes in memory (estimated size 44.6 KiB, free 9.4 GiB)
# 12:49:01.943 [dispatcher-BlockManagerMaster] INFO  org.apache.spark.storage.BlockManagerInfo - Added broadcast_6_piece0 in memory on spark-master:7082 (size: 44.6 KiB, free: 9.4 GiB)
# 12:49:01.944 [Thread-4] INFO  org.apache.spark.SparkContext - Created broadcast 6 from textFile at ReadWrite.scala:587
# 12:49:01.967 [Thread-4] INFO  org.apache.hadoop.mapred.FileInputFormat - Total input files to process : 1
# 12:49:01.993 [Thread-4] INFO  org.apache.spark.SparkContext - Starting job: first at ReadWrite.scala:587
# 12:49:01.996 [dag-scheduler-event-loop] INFO  org.apache.spark.scheduler.DAGScheduler - Got job 3 (first at ReadWrite.scala:587) with 1 output partitions
# 12:49:01.996 [dag-scheduler-event-loop] INFO  org.apache.spark.scheduler.DAGScheduler - Final stage: ResultStage 3 (first at ReadWrite.scala:587)
# 12:49:01.996 [dag-scheduler-event-loop] INFO  org.apache.spark.scheduler.DAGScheduler - Parents of final stage: List()
# 12:49:01.997 [dag-scheduler-event-loop] INFO  org.apache.spark.scheduler.DAGScheduler - Missing parents: List()
# 12:49:01.998 [dag-scheduler-event-loop] INFO  org.apache.spark.scheduler.DAGScheduler - Submitting ResultStage 3 (file:/root/cache_pretrained/recognize_entities_dl_en_4.4.2_3.4_1685041151703/stages/1_SENTENCE_328d8a47c1a8/metadata MapPartitionsRDD[7] at textFile at ReadWrite.scala:587), which has no missing parents
# 12:49:02.000 [dag-scheduler-event-loop] INFO  org.apache.spark.storage.memory.MemoryStore - Block broadcast_7 stored as values in memory (estimated size 5.1 KiB, free 9.4 GiB)
# 12:49:02.003 [dag-scheduler-event-loop] INFO  org.apache.spark.storage.memory.MemoryStore - Block broadcast_7_piece0 stored as bytes in memory (estimated size 3.0 KiB, free 9.4 GiB)
# 12:49:02.004 [dispatcher-BlockManagerMaster] INFO  org.apache.spark.storage.BlockManagerInfo - Added broadcast_7_piece0 in memory on spark-master:7082 (size: 3.0 KiB, free: 9.4 GiB)
# 12:49:02.004 [dag-scheduler-event-loop] INFO  org.apache.spark.SparkContext - Created broadcast 7 from broadcast at DAGScheduler.scala:1585
# 12:49:02.005 [dag-scheduler-event-loop] INFO  org.apache.spark.scheduler.DAGScheduler - Submitting 1 missing tasks from ResultStage 3 (file:/root/cache_pretrained/recognize_entities_dl_en_4.4.2_3.4_1685041151703/stages/1_SENTENCE_328d8a47c1a8/metadata MapPartitionsRDD[7] at textFile at ReadWrite.scala:587) (first 15 tasks are for partitions Vector(0))
# 12:49:02.005 [dag-scheduler-event-loop] INFO  org.apache.spark.scheduler.TaskSchedulerImpl - Adding task set 3.0 with 1 tasks resource profile 0
# 12:49:02.005 [dag-scheduler-event-loop] INFO  org.apache.spark.scheduler.FairSchedulableBuilder - Added task set TaskSet_3.0 tasks to pool default
# 12:49:02.007 [dispatcher-event-loop-1] INFO  org.apache.spark.scheduler.TaskSetManager - Starting task 0.0 in stage 3.0 (TID 3) (0ea22e89e591, executor driver, partition 0, PROCESS_LOCAL, 37295 bytes)
# 12:49:02.007 [Executor task launch worker for task 0.0 in stage 3.0 (TID 3)] INFO  org.apache.spark.executor.Executor - Running task 0.0 in stage 3.0 (TID 3)
# 12:49:02.012 [Executor task launch worker for task 0.0 in stage 3.0 (TID 3)] INFO  org.apache.spark.rdd.HadoopRDD - Input split: file:/root/cache_pretrained/recognize_entities_dl_en_4.4.2_3.4_1685041151703/stages/1_SENTENCE_328d8a47c1a8/metadata/part-00000:0+433
# 12:49:02.023 [Executor task launch worker for task 0.0 in stage 3.0 (TID 3)] INFO  org.apache.spark.executor.Executor - Finished task 0.0 in stage 3.0 (TID 3). 1375 bytes result sent to driver
# 12:49:02.025 [task-result-getter-3] INFO  org.apache.spark.scheduler.TaskSetManager - Finished task 0.0 in stage 3.0 (TID 3) in 19 ms on 0ea22e89e591 (executor driver) (1/1)
# 12:49:02.025 [task-result-getter-3] INFO  org.apache.spark.scheduler.TaskSchedulerImpl - Removed TaskSet 3.0, whose tasks have all completed, from pool default
# 12:49:02.026 [dag-scheduler-event-loop] INFO  org.apache.spark.scheduler.DAGScheduler - ResultStage 3 (first at ReadWrite.scala:587) finished in 0.028 s
# 12:49:02.027 [dag-scheduler-event-loop] INFO  org.apache.spark.scheduler.DAGScheduler - Job 3 is finished. Cancelling potential speculative or zombie tasks for this job
# 12:49:02.027 [dag-scheduler-event-loop] INFO  org.apache.spark.scheduler.TaskSchedulerImpl - Killing all running tasks in stage 3: Stage finished
# 12:49:02.027 [Thread-4] INFO  org.apache.spark.scheduler.DAGScheduler - Job 3 finished: first at ReadWrite.scala:587, took 0.033526 s
# 12:49:02.052 [Thread-4] INFO  org.apache.spark.storage.memory.MemoryStore - Block broadcast_8 stored as values in memory (estimated size 225.4 KiB, free 9.4 GiB)
# 12:49:02.083 [Thread-4] INFO  org.apache.spark.storage.memory.MemoryStore - Block broadcast_8_piece0 stored as bytes in memory (estimated size 44.6 KiB, free 9.4 GiB)
# 12:49:02.085 [dispatcher-BlockManagerMaster] INFO  org.apache.spark.storage.BlockManagerInfo - Added broadcast_8_piece0 in memory on spark-master:7082 (size: 44.6 KiB, free: 9.4 GiB)
# 12:49:02.102 [Thread-4] INFO  org.apache.spark.SparkContext - Created broadcast 8 from textFile at ReadWrite.scala:587
# 12:49:02.204 [Thread-4] INFO  org.apache.hadoop.mapred.FileInputFormat - Total input files to process : 1
# 12:49:02.216 [Thread-4] INFO  org.apache.spark.SparkContext - Starting job: first at ReadWrite.scala:587
# 12:49:02.219 [dag-scheduler-event-loop] INFO  org.apache.spark.scheduler.DAGScheduler - Got job 4 (first at ReadWrite.scala:587) with 1 output partitions
# 12:49:02.219 [dag-scheduler-event-loop] INFO  org.apache.spark.scheduler.DAGScheduler - Final stage: ResultStage 4 (first at ReadWrite.scala:587)
# 12:49:02.219 [dag-scheduler-event-loop] INFO  org.apache.spark.scheduler.DAGScheduler - Parents of final stage: List()
# 12:49:02.219 [dag-scheduler-event-loop] INFO  org.apache.spark.scheduler.DAGScheduler - Missing parents: List()
# 12:49:02.221 [dag-scheduler-event-loop] INFO  org.apache.spark.scheduler.DAGScheduler - Submitting ResultStage 4 (file:/root/cache_pretrained/recognize_entities_dl_en_4.4.2_3.4_1685041151703/stages/1_SENTENCE_328d8a47c1a8/metadata MapPartitionsRDD[9] at textFile at ReadWrite.scala:587), which has no missing parents
# 12:49:02.227 [dag-scheduler-event-loop] INFO  org.apache.spark.storage.memory.MemoryStore - Block broadcast_9 stored as values in memory (estimated size 5.1 KiB, free 9.4 GiB)
# 12:49:02.230 [dag-scheduler-event-loop] INFO  org.apache.spark.storage.memory.MemoryStore - Block broadcast_9_piece0 stored as bytes in memory (estimated size 3.0 KiB, free 9.4 GiB)
# 12:49:02.230 [dispatcher-BlockManagerMaster] INFO  org.apache.spark.storage.BlockManagerInfo - Added broadcast_9_piece0 in memory on spark-master:7082 (size: 3.0 KiB, free: 9.4 GiB)
# 12:49:02.231 [dag-scheduler-event-loop] INFO  org.apache.spark.SparkContext - Created broadcast 9 from broadcast at DAGScheduler.scala:1585
# 12:49:02.232 [dag-scheduler-event-loop] INFO  org.apache.spark.scheduler.DAGScheduler - Submitting 1 missing tasks from ResultStage 4 (file:/root/cache_pretrained/recognize_entities_dl_en_4.4.2_3.4_1685041151703/stages/1_SENTENCE_328d8a47c1a8/metadata MapPartitionsRDD[9] at textFile at ReadWrite.scala:587) (first 15 tasks are for partitions Vector(0))
# 12:49:02.232 [dag-scheduler-event-loop] INFO  org.apache.spark.scheduler.TaskSchedulerImpl - Adding task set 4.0 with 1 tasks resource profile 0
# 12:49:02.232 [dag-scheduler-event-loop] INFO  org.apache.spark.scheduler.FairSchedulableBuilder - Added task set TaskSet_4.0 tasks to pool default
# 12:49:02.234 [dispatcher-event-loop-5] INFO  org.apache.spark.scheduler.TaskSetManager - Starting task 0.0 in stage 4.0 (TID 4) (0ea22e89e591, executor driver, partition 0, PROCESS_LOCAL, 37295 bytes)
# 12:49:02.236 [Executor task launch worker for task 0.0 in stage 4.0 (TID 4)] INFO  org.apache.spark.executor.Executor - Running task 0.0 in stage 4.0 (TID 4)
# 12:49:02.247 [Executor task launch worker for task 0.0 in stage 4.0 (TID 4)] INFO  org.apache.spark.rdd.HadoopRDD - Input split: file:/root/cache_pretrained/recognize_entities_dl_en_4.4.2_3.4_1685041151703/stages/1_SENTENCE_328d8a47c1a8/metadata/part-00000:0+433
# 12:49:02.251 [Executor task launch worker for task 0.0 in stage 4.0 (TID 4)] INFO  org.apache.spark.executor.Executor - Finished task 0.0 in stage 4.0 (TID 4). 1332 bytes result sent to driver
# 12:49:02.252 [task-result-getter-0] INFO  org.apache.spark.scheduler.TaskSetManager - Finished task 0.0 in stage 4.0 (TID 4) in 19 ms on 0ea22e89e591 (executor driver) (1/1)
# 12:49:02.252 [task-result-getter-0] INFO  org.apache.spark.scheduler.TaskSchedulerImpl - Removed TaskSet 4.0, whose tasks have all completed, from pool default
# 12:49:02.253 [dag-scheduler-event-loop] INFO  org.apache.spark.scheduler.DAGScheduler - ResultStage 4 (first at ReadWrite.scala:587) finished in 0.030 s
# 12:49:02.253 [dag-scheduler-event-loop] INFO  org.apache.spark.scheduler.DAGScheduler - Job 4 is finished. Cancelling potential speculative or zombie tasks for this job
# 12:49:02.253 [dag-scheduler-event-loop] INFO  org.apache.spark.scheduler.TaskSchedulerImpl - Killing all running tasks in stage 4: Stage finished
# 12:49:02.253 [Thread-4] INFO  org.apache.spark.scheduler.DAGScheduler - Job 4 finished: first at ReadWrite.scala:587, took 0.036380 s
# 12:49:02.268 [Thread-4] INFO  org.apache.spark.storage.memory.MemoryStore - Block broadcast_10 stored as values in memory (estimated size 225.4 KiB, free 9.4 GiB)
# 12:49:02.275 [Thread-4] INFO  org.apache.spark.storage.memory.MemoryStore - Block broadcast_10_piece0 stored as bytes in memory (estimated size 44.6 KiB, free 9.4 GiB)
# 12:49:02.275 [dispatcher-BlockManagerMaster] INFO  org.apache.spark.storage.BlockManagerInfo - Added broadcast_10_piece0 in memory on spark-master:7082 (size: 44.6 KiB, free: 9.4 GiB)
# 12:49:02.276 [Thread-4] INFO  org.apache.spark.SparkContext - Created broadcast 10 from textFile at ReadWrite.scala:587
# 12:49:02.295 [Thread-4] INFO  org.apache.hadoop.mapred.FileInputFormat - Total input files to process : 1
# 12:49:02.305 [Thread-4] INFO  org.apache.spark.SparkContext - Starting job: first at ReadWrite.scala:587
# 12:49:02.306 [dag-scheduler-event-loop] INFO  org.apache.spark.scheduler.DAGScheduler - Got job 5 (first at ReadWrite.scala:587) with 1 output partitions
# 12:49:02.306 [dag-scheduler-event-loop] INFO  org.apache.spark.scheduler.DAGScheduler - Final stage: ResultStage 5 (first at ReadWrite.scala:587)
# 12:49:02.306 [dag-scheduler-event-loop] INFO  org.apache.spark.scheduler.DAGScheduler - Parents of final stage: List()
# 12:49:02.306 [dag-scheduler-event-loop] INFO  org.apache.spark.scheduler.DAGScheduler - Missing parents: List()
# 12:49:02.306 [dag-scheduler-event-loop] INFO  org.apache.spark.scheduler.DAGScheduler - Submitting ResultStage 5 (file:/root/cache_pretrained/recognize_entities_dl_en_4.4.2_3.4_1685041151703/stages/2_REGEX_TOKENIZER_959cd9403d10/metadata MapPartitionsRDD[11] at textFile at ReadWrite.scala:587), which has no missing parents
# 12:49:02.309 [dag-scheduler-event-loop] INFO  org.apache.spark.storage.memory.MemoryStore - Block broadcast_11 stored as values in memory (estimated size 5.1 KiB, free 9.4 GiB)
# 12:49:02.362 [dag-scheduler-event-loop] INFO  org.apache.spark.storage.memory.MemoryStore - Block broadcast_11_piece0 stored as bytes in memory (estimated size 3.0 KiB, free 9.4 GiB)
# 12:49:02.365 [dispatcher-BlockManagerMaster] INFO  org.apache.spark.storage.BlockManagerInfo - Added broadcast_11_piece0 in memory on spark-master:7082 (size: 3.0 KiB, free: 9.4 GiB)
# 12:49:02.366 [dag-scheduler-event-loop] INFO  org.apache.spark.SparkContext - Created broadcast 11 from broadcast at DAGScheduler.scala:1585
# 12:49:02.367 [dag-scheduler-event-loop] INFO  org.apache.spark.scheduler.DAGScheduler - Submitting 1 missing tasks from ResultStage 5 (file:/root/cache_pretrained/recognize_entities_dl_en_4.4.2_3.4_1685041151703/stages/2_REGEX_TOKENIZER_959cd9403d10/metadata MapPartitionsRDD[11] at textFile at ReadWrite.scala:587) (first 15 tasks are for partitions Vector(0))
# 12:49:02.367 [dag-scheduler-event-loop] INFO  org.apache.spark.scheduler.TaskSchedulerImpl - Adding task set 5.0 with 1 tasks resource profile 0
# 12:49:02.368 [dag-scheduler-event-loop] INFO  org.apache.spark.scheduler.FairSchedulableBuilder - Added task set TaskSet_5.0 tasks to pool default
# 12:49:02.371 [dispatcher-event-loop-1] INFO  org.apache.spark.scheduler.TaskSetManager - Starting task 0.0 in stage 5.0 (TID 5) (0ea22e89e591, executor driver, partition 0, PROCESS_LOCAL, 37303 bytes)
# 12:49:02.372 [Executor task launch worker for task 0.0 in stage 5.0 (TID 5)] INFO  org.apache.spark.executor.Executor - Running task 0.0 in stage 5.0 (TID 5)
# 12:49:02.384 [Executor task launch worker for task 0.0 in stage 5.0 (TID 5)] INFO  org.apache.spark.rdd.HadoopRDD - Input split: file:/root/cache_pretrained/recognize_entities_dl_en_4.4.2_3.4_1685041151703/stages/2_REGEX_TOKENIZER_959cd9403d10/metadata/part-00000:0+462
# 12:49:02.392 [Executor task launch worker for task 0.0 in stage 5.0 (TID 5)] INFO  org.apache.spark.executor.Executor - Finished task 0.0 in stage 5.0 (TID 5). 1404 bytes result sent to driver
# 12:49:02.397 [task-result-getter-1] INFO  org.apache.spark.scheduler.TaskSetManager - Finished task 0.0 in stage 5.0 (TID 5) in 28 ms on 0ea22e89e591 (executor driver) (1/1)
# 12:49:02.397 [task-result-getter-1] INFO  org.apache.spark.scheduler.TaskSchedulerImpl - Removed TaskSet 5.0, whose tasks have all completed, from pool default
# 12:49:02.398 [dag-scheduler-event-loop] INFO  org.apache.spark.scheduler.DAGScheduler - ResultStage 5 (first at ReadWrite.scala:587) finished in 0.091 s
# 12:49:02.398 [dag-scheduler-event-loop] INFO  org.apache.spark.scheduler.DAGScheduler - Job 5 is finished. Cancelling potential speculative or zombie tasks for this job
# 12:49:02.398 [dag-scheduler-event-loop] INFO  org.apache.spark.scheduler.TaskSchedulerImpl - Killing all running tasks in stage 5: Stage finished
# 12:49:02.401 [Thread-4] INFO  org.apache.spark.scheduler.DAGScheduler - Job 5 finished: first at ReadWrite.scala:587, took 0.095445 s
# 12:49:02.429 [dispatcher-BlockManagerMaster] INFO  org.apache.spark.storage.BlockManagerInfo - Removed broadcast_2_piece0 on spark-master:7082 in memory (size: 44.6 KiB, free: 9.4 GiB)
# 12:49:02.429 [Thread-4] INFO  org.apache.spark.storage.memory.MemoryStore - Block broadcast_12 stored as values in memory (estimated size 225.4 KiB, free 9.4 GiB)
# 12:49:02.443 [dispatcher-BlockManagerMaster] INFO  org.apache.spark.storage.BlockManagerInfo - Removed broadcast_1_piece0 on spark-master:7082 in memory (size: 2.9 KiB, free: 9.4 GiB)
# 12:49:02.449 [Thread-4] INFO  org.apache.spark.storage.memory.MemoryStore - Block broadcast_12_piece0 stored as bytes in memory (estimated size 44.6 KiB, free 9.4 GiB)
# 12:49:02.450 [dispatcher-BlockManagerMaster] INFO  org.apache.spark.storage.BlockManagerInfo - Added broadcast_12_piece0 in memory on spark-master:7082 (size: 44.6 KiB, free: 9.4 GiB)
# 12:49:02.452 [Thread-4] INFO  org.apache.spark.SparkContext - Created broadcast 12 from textFile at ReadWrite.scala:587
# 12:49:02.454 [dispatcher-BlockManagerMaster] INFO  org.apache.spark.storage.BlockManagerInfo - Removed broadcast_9_piece0 on spark-master:7082 in memory (size: 3.0 KiB, free: 9.4 GiB)
# 12:49:02.461 [dispatcher-BlockManagerMaster] INFO  org.apache.spark.storage.BlockManagerInfo - Removed broadcast_4_piece0 on spark-master:7082 in memory (size: 44.6 KiB, free: 9.4 GiB)
# 12:49:02.468 [dispatcher-BlockManagerMaster] INFO  org.apache.spark.storage.BlockManagerInfo - Removed broadcast_7_piece0 on spark-master:7082 in memory (size: 3.0 KiB, free: 9.4 GiB)
# 12:49:02.485 [dispatcher-BlockManagerMaster] INFO  org.apache.spark.storage.BlockManagerInfo - Removed broadcast_0_piece0 on spark-master:7082 in memory (size: 44.6 KiB, free: 9.4 GiB)
# 12:49:02.488 [Thread-4] INFO  org.apache.hadoop.mapred.FileInputFormat - Total input files to process : 1
# 12:49:02.498 [dispatcher-BlockManagerMaster] INFO  org.apache.spark.storage.BlockManagerInfo - Removed broadcast_5_piece0 on spark-master:7082 in memory (size: 3.0 KiB, free: 9.4 GiB)
# 12:49:02.501 [Thread-4] INFO  org.apache.spark.SparkContext - Starting job: first at ReadWrite.scala:587
# 12:49:02.502 [dag-scheduler-event-loop] INFO  org.apache.spark.scheduler.DAGScheduler - Got job 6 (first at ReadWrite.scala:587) with 1 output partitions
# 12:49:02.502 [dag-scheduler-event-loop] INFO  org.apache.spark.scheduler.DAGScheduler - Final stage: ResultStage 6 (first at ReadWrite.scala:587)
# 12:49:02.502 [dag-scheduler-event-loop] INFO  org.apache.spark.scheduler.DAGScheduler - Parents of final stage: List()
# 12:49:02.503 [dag-scheduler-event-loop] INFO  org.apache.spark.scheduler.DAGScheduler - Missing parents: List()
# 12:49:02.503 [dag-scheduler-event-loop] INFO  org.apache.spark.scheduler.DAGScheduler - Submitting ResultStage 6 (file:/root/cache_pretrained/recognize_entities_dl_en_4.4.2_3.4_1685041151703/stages/2_REGEX_TOKENIZER_959cd9403d10/metadata MapPartitionsRDD[13] at textFile at ReadWrite.scala:587), which has no missing parents
# 12:49:02.506 [dag-scheduler-event-loop] INFO  org.apache.spark.storage.memory.MemoryStore - Block broadcast_13 stored as values in memory (estimated size 5.1 KiB, free 9.4 GiB)
# 12:49:02.506 [dispatcher-BlockManagerMaster] INFO  org.apache.spark.storage.BlockManagerInfo - Removed broadcast_6_piece0 on spark-master:7082 in memory (size: 44.6 KiB, free: 9.4 GiB)
# 12:49:02.509 [dag-scheduler-event-loop] INFO  org.apache.spark.storage.memory.MemoryStore - Block broadcast_13_piece0 stored as bytes in memory (estimated size 3.0 KiB, free 9.4 GiB)
# 12:49:02.510 [dispatcher-BlockManagerMaster] INFO  org.apache.spark.storage.BlockManagerInfo - Added broadcast_13_piece0 in memory on spark-master:7082 (size: 3.0 KiB, free: 9.4 GiB)
# 12:49:02.510 [dag-scheduler-event-loop] INFO  org.apache.spark.SparkContext - Created broadcast 13 from broadcast at DAGScheduler.scala:1585
# 12:49:02.511 [dag-scheduler-event-loop] INFO  org.apache.spark.scheduler.DAGScheduler - Submitting 1 missing tasks from ResultStage 6 (file:/root/cache_pretrained/recognize_entities_dl_en_4.4.2_3.4_1685041151703/stages/2_REGEX_TOKENIZER_959cd9403d10/metadata MapPartitionsRDD[13] at textFile at ReadWrite.scala:587) (first 15 tasks are for partitions Vector(0))
# 12:49:02.511 [dag-scheduler-event-loop] INFO  org.apache.spark.scheduler.TaskSchedulerImpl - Adding task set 6.0 with 1 tasks resource profile 0
# 12:49:02.511 [dag-scheduler-event-loop] INFO  org.apache.spark.scheduler.FairSchedulableBuilder - Added task set TaskSet_6.0 tasks to pool default
# 12:49:02.512 [dispatcher-event-loop-5] INFO  org.apache.spark.scheduler.TaskSetManager - Starting task 0.0 in stage 6.0 (TID 6) (0ea22e89e591, executor driver, partition 0, PROCESS_LOCAL, 37303 bytes)
# 12:49:02.603 [dispatcher-BlockManagerMaster] INFO  org.apache.spark.storage.BlockManagerInfo - Removed broadcast_8_piece0 on spark-master:7082 in memory (size: 44.6 KiB, free: 9.4 GiB)
# 12:49:02.605 [Executor task launch worker for task 0.0 in stage 6.0 (TID 6)] INFO  org.apache.spark.executor.Executor - Running task 0.0 in stage 6.0 (TID 6)
# 12:49:02.613 [Executor task launch worker for task 0.0 in stage 6.0 (TID 6)] INFO  org.apache.spark.rdd.HadoopRDD - Input split: file:/root/cache_pretrained/recognize_entities_dl_en_4.4.2_3.4_1685041151703/stages/2_REGEX_TOKENIZER_959cd9403d10/metadata/part-00000:0+462
# 12:49:02.622 [dispatcher-BlockManagerMaster] INFO  org.apache.spark.storage.BlockManagerInfo - Removed broadcast_3_piece0 on spark-master:7082 in memory (size: 3.0 KiB, free: 9.4 GiB)
# 12:49:02.636 [Executor task launch worker for task 0.0 in stage 6.0 (TID 6)] INFO  org.apache.spark.executor.Executor - Finished task 0.0 in stage 6.0 (TID 6). 1404 bytes result sent to driver
# 12:49:02.704 [task-result-getter-2] INFO  org.apache.spark.scheduler.TaskSetManager - Finished task 0.0 in stage 6.0 (TID 6) in 192 ms on 0ea22e89e591 (executor driver) (1/1)
# 12:49:02.724 [task-result-getter-2] INFO  org.apache.spark.scheduler.TaskSchedulerImpl - Removed TaskSet 6.0, whose tasks have all completed, from pool default
# 12:49:02.725 [dag-scheduler-event-loop] INFO  org.apache.spark.scheduler.DAGScheduler - ResultStage 6 (first at ReadWrite.scala:587) finished in 0.221 s
# 12:49:02.733 [dag-scheduler-event-loop] INFO  org.apache.spark.scheduler.DAGScheduler - Job 6 is finished. Cancelling potential speculative or zombie tasks for this job
# 12:49:02.734 [dag-scheduler-event-loop] INFO  org.apache.spark.scheduler.TaskSchedulerImpl - Killing all running tasks in stage 6: Stage finished
# 12:49:02.744 [Thread-4] INFO  org.apache.spark.scheduler.DAGScheduler - Job 6 finished: first at ReadWrite.scala:587, took 0.242338 s
# 12:49:02.978 [Thread-4] INFO  org.apache.spark.storage.memory.MemoryStore - Block broadcast_14 stored as values in memory (estimated size 225.4 KiB, free 9.4 GiB)
# 12:49:02.991 [Thread-4] INFO  org.apache.spark.storage.memory.MemoryStore - Block broadcast_14_piece0 stored as bytes in memory (estimated size 44.6 KiB, free 9.4 GiB)
# 12:49:02.992 [dispatcher-BlockManagerMaster] INFO  org.apache.spark.storage.BlockManagerInfo - Added broadcast_14_piece0 in memory on spark-master:7082 (size: 44.6 KiB, free: 9.4 GiB)
# 12:49:02.993 [Thread-4] INFO  org.apache.spark.SparkContext - Created broadcast 14 from objectFile at Feature.scala:182
# 12:49:03.067 [Thread-4] INFO  org.apache.hadoop.mapred.FileInputFormat - Total input files to process : 8
# 12:49:03.082 [Thread-4] INFO  org.apache.spark.SparkContext - Starting job: first at Feature.scala:182
# 12:49:03.083 [dag-scheduler-event-loop] INFO  org.apache.spark.scheduler.DAGScheduler - Got job 7 (first at Feature.scala:182) with 1 output partitions
# 12:49:03.083 [dag-scheduler-event-loop] INFO  org.apache.spark.scheduler.DAGScheduler - Final stage: ResultStage 7 (first at Feature.scala:182)
# 12:49:03.083 [dag-scheduler-event-loop] INFO  org.apache.spark.scheduler.DAGScheduler - Parents of final stage: List()
# 12:49:03.083 [dag-scheduler-event-loop] INFO  org.apache.spark.scheduler.DAGScheduler - Missing parents: List()
# 12:49:03.085 [dag-scheduler-event-loop] INFO  org.apache.spark.scheduler.DAGScheduler - Submitting ResultStage 7 (MapPartitionsRDD[15] at objectFile at Feature.scala:182), which has no missing parents
# 12:49:03.089 [dag-scheduler-event-loop] INFO  org.apache.spark.storage.memory.MemoryStore - Block broadcast_15 stored as values in memory (estimated size 5.5 KiB, free 9.4 GiB)
# 12:49:03.092 [dag-scheduler-event-loop] INFO  org.apache.spark.storage.memory.MemoryStore - Block broadcast_15_piece0 stored as bytes in memory (estimated size 3.3 KiB, free 9.4 GiB)
# 12:49:03.093 [dispatcher-BlockManagerMaster] INFO  org.apache.spark.storage.BlockManagerInfo - Added broadcast_15_piece0 in memory on spark-master:7082 (size: 3.3 KiB, free: 9.4 GiB)
# 12:49:03.093 [dag-scheduler-event-loop] INFO  org.apache.spark.SparkContext - Created broadcast 15 from broadcast at DAGScheduler.scala:1585
# 12:49:03.094 [dag-scheduler-event-loop] INFO  org.apache.spark.scheduler.DAGScheduler - Submitting 1 missing tasks from ResultStage 7 (MapPartitionsRDD[15] at objectFile at Feature.scala:182) (first 15 tasks are for partitions Vector(0))
# 12:49:03.094 [dag-scheduler-event-loop] INFO  org.apache.spark.scheduler.TaskSchedulerImpl - Adding task set 7.0 with 1 tasks resource profile 0
# 12:49:03.096 [dag-scheduler-event-loop] INFO  org.apache.spark.scheduler.FairSchedulableBuilder - Added task set TaskSet_7.0 tasks to pool default
# 12:49:03.098 [dispatcher-event-loop-3] INFO  org.apache.spark.scheduler.TaskSetManager - Starting task 0.0 in stage 7.0 (TID 7) (0ea22e89e591, executor driver, partition 0, PROCESS_LOCAL, 37307 bytes)
# 12:49:03.099 [Executor task launch worker for task 0.0 in stage 7.0 (TID 7)] INFO  org.apache.spark.executor.Executor - Running task 0.0 in stage 7.0 (TID 7)
# 12:49:03.106 [Executor task launch worker for task 0.0 in stage 7.0 (TID 7)] INFO  org.apache.spark.rdd.HadoopRDD - Input split: file:/root/cache_pretrained/recognize_entities_dl_en_4.4.2_3.4_1685041151703/stages/2_REGEX_TOKENIZER_959cd9403d10/fields/rules/part-00004:0+95
# 12:49:03.129 [Executor task launch worker for task 0.0 in stage 7.0 (TID 7)] INFO  org.apache.spark.executor.Executor - Finished task 0.0 in stage 7.0 (TID 7). 941 bytes result sent to driver
# 12:49:03.130 [task-result-getter-3] INFO  org.apache.spark.scheduler.TaskSetManager - Finished task 0.0 in stage 7.0 (TID 7) in 33 ms on 0ea22e89e591 (executor driver) (1/1)
# 12:49:03.130 [task-result-getter-3] INFO  org.apache.spark.scheduler.TaskSchedulerImpl - Removed TaskSet 7.0, whose tasks have all completed, from pool default
# 12:49:03.131 [dag-scheduler-event-loop] INFO  org.apache.spark.scheduler.DAGScheduler - ResultStage 7 (first at Feature.scala:182) finished in 0.044 s
# 12:49:03.131 [dag-scheduler-event-loop] INFO  org.apache.spark.scheduler.DAGScheduler - Job 7 is finished. Cancelling potential speculative or zombie tasks for this job
# 12:49:03.131 [dag-scheduler-event-loop] INFO  org.apache.spark.scheduler.TaskSchedulerImpl - Killing all running tasks in stage 7: Stage finished
# 12:49:03.132 [Thread-4] INFO  org.apache.spark.scheduler.DAGScheduler - Job 7 finished: first at Feature.scala:182, took 0.050321 s
# 12:49:03.144 [Thread-4] INFO  org.apache.spark.SparkContext - Starting job: first at Feature.scala:182
# 12:49:03.145 [dag-scheduler-event-loop] INFO  org.apache.spark.scheduler.DAGScheduler - Got job 8 (first at Feature.scala:182) with 4 output partitions
# 12:49:03.145 [dag-scheduler-event-loop] INFO  org.apache.spark.scheduler.DAGScheduler - Final stage: ResultStage 8 (first at Feature.scala:182)
# 12:49:03.145 [dag-scheduler-event-loop] INFO  org.apache.spark.scheduler.DAGScheduler - Parents of final stage: List()
# 12:49:03.145 [dag-scheduler-event-loop] INFO  org.apache.spark.scheduler.DAGScheduler - Missing parents: List()
# 12:49:03.146 [dag-scheduler-event-loop] INFO  org.apache.spark.scheduler.DAGScheduler - Submitting ResultStage 8 (MapPartitionsRDD[15] at objectFile at Feature.scala:182), which has no missing parents
# 12:49:03.147 [dag-scheduler-event-loop] INFO  org.apache.spark.storage.memory.MemoryStore - Block broadcast_16 stored as values in memory (estimated size 5.5 KiB, free 9.4 GiB)
# 12:49:03.151 [dag-scheduler-event-loop] INFO  org.apache.spark.storage.memory.MemoryStore - Block broadcast_16_piece0 stored as bytes in memory (estimated size 3.3 KiB, free 9.4 GiB)
# 12:49:03.151 [dispatcher-BlockManagerMaster] INFO  org.apache.spark.storage.BlockManagerInfo - Added broadcast_16_piece0 in memory on spark-master:7082 (size: 3.3 KiB, free: 9.4 GiB)
# 12:49:03.152 [dag-scheduler-event-loop] INFO  org.apache.spark.SparkContext - Created broadcast 16 from broadcast at DAGScheduler.scala:1585
# 12:49:03.152 [dag-scheduler-event-loop] INFO  org.apache.spark.scheduler.DAGScheduler - Submitting 4 missing tasks from ResultStage 8 (MapPartitionsRDD[15] at objectFile at Feature.scala:182) (first 15 tasks are for partitions Vector(1, 2, 3, 4))
# 12:49:03.152 [dag-scheduler-event-loop] INFO  org.apache.spark.scheduler.TaskSchedulerImpl - Adding task set 8.0 with 4 tasks resource profile 0
# 12:49:03.153 [dag-scheduler-event-loop] INFO  org.apache.spark.scheduler.FairSchedulableBuilder - Added task set TaskSet_8.0 tasks to pool default
# 12:49:03.154 [dispatcher-event-loop-0] INFO  org.apache.spark.scheduler.TaskSetManager - Starting task 0.0 in stage 8.0 (TID 8) (0ea22e89e591, executor driver, partition 1, PROCESS_LOCAL, 37307 bytes)
# 12:49:03.155 [dispatcher-event-loop-0] INFO  org.apache.spark.scheduler.TaskSetManager - Starting task 1.0 in stage 8.0 (TID 9) (0ea22e89e591, executor driver, partition 2, PROCESS_LOCAL, 37307 bytes)
# 12:49:03.156 [dispatcher-event-loop-0] INFO  org.apache.spark.scheduler.TaskSetManager - Starting task 2.0 in stage 8.0 (TID 10) (0ea22e89e591, executor driver, partition 3, PROCESS_LOCAL, 37307 bytes)
# 12:49:03.157 [dispatcher-event-loop-0] INFO  org.apache.spark.scheduler.TaskSetManager - Starting task 3.0 in stage 8.0 (TID 11) (0ea22e89e591, executor driver, partition 4, PROCESS_LOCAL, 37307 bytes)
# 12:49:03.157 [Executor task launch worker for task 0.0 in stage 8.0 (TID 8)] INFO  org.apache.spark.executor.Executor - Running task 0.0 in stage 8.0 (TID 8)
# 12:49:03.158 [Executor task launch worker for task 1.0 in stage 8.0 (TID 9)] INFO  org.apache.spark.executor.Executor - Running task 1.0 in stage 8.0 (TID 9)
# 12:49:03.159 [Executor task launch worker for task 2.0 in stage 8.0 (TID 10)] INFO  org.apache.spark.executor.Executor - Running task 2.0 in stage 8.0 (TID 10)
# 12:49:03.161 [Executor task launch worker for task 3.0 in stage 8.0 (TID 11)] INFO  org.apache.spark.executor.Executor - Running task 3.0 in stage 8.0 (TID 11)
# 12:49:03.168 [Executor task launch worker for task 0.0 in stage 8.0 (TID 8)] INFO  org.apache.spark.rdd.HadoopRDD - Input split: file:/root/cache_pretrained/recognize_entities_dl_en_4.4.2_3.4_1685041151703/stages/2_REGEX_TOKENIZER_959cd9403d10/fields/rules/part-00000:0+95
# 12:49:03.169 [Executor task launch worker for task 3.0 in stage 8.0 (TID 11)] INFO  org.apache.spark.rdd.HadoopRDD - Input split: file:/root/cache_pretrained/recognize_entities_dl_en_4.4.2_3.4_1685041151703/stages/2_REGEX_TOKENIZER_959cd9403d10/fields/rules/part-00005:0+95
# 12:49:03.169 [Executor task launch worker for task 2.0 in stage 8.0 (TID 10)] INFO  org.apache.spark.rdd.HadoopRDD - Input split: file:/root/cache_pretrained/recognize_entities_dl_en_4.4.2_3.4_1685041151703/stages/2_REGEX_TOKENIZER_959cd9403d10/fields/rules/part-00002:0+95
# 12:49:03.169 [Executor task launch worker for task 1.0 in stage 8.0 (TID 9)] INFO  org.apache.spark.rdd.HadoopRDD - Input split: file:/root/cache_pretrained/recognize_entities_dl_en_4.4.2_3.4_1685041151703/stages/2_REGEX_TOKENIZER_959cd9403d10/fields/rules/part-00006:0+95
# 12:49:03.174 [Executor task launch worker for task 1.0 in stage 8.0 (TID 9)] INFO  org.apache.spark.executor.Executor - Finished task 1.0 in stage 8.0 (TID 9). 898 bytes result sent to driver
# 12:49:03.175 [task-result-getter-0] INFO  org.apache.spark.scheduler.TaskSetManager - Finished task 1.0 in stage 8.0 (TID 9) in 21 ms on 0ea22e89e591 (executor driver) (1/4)
# 12:49:03.175 [Executor task launch worker for task 3.0 in stage 8.0 (TID 11)] INFO  org.apache.spark.executor.Executor - Finished task 3.0 in stage 8.0 (TID 11). 898 bytes result sent to driver
# 12:49:03.176 [task-result-getter-1] INFO  org.apache.spark.scheduler.TaskSetManager - Finished task 3.0 in stage 8.0 (TID 11) in 20 ms on 0ea22e89e591 (executor driver) (2/4)
# ...
# See below for details of this colocation group:
# Colocation Debug Info:
# Colocation group had the following types and supported devices:
# Root Member(assigned_device_name_index_=-1 requested_device_name_='/device:GPU:0' assigned_device_name_='' resource_device_name_='/device:GPU:0' supported_device_types_=[CPU] possible_devices_=[]
# ApplyAdam: CPU
# Assign: CPU
# VariableV2: CPU
# Identity: CPU
# Add: CPU
# Mul: CPU
# Sub: CPU
# RandomUniform: CPU
# Const: CPU
#
# Colocation members, user-requested devices, and framework assigned devices, if any:
#   context_repr/b/Initializer/random_uniform/shape (Const)
#   context_repr/b/Initializer/random_uniform/min (Const)
#   context_repr/b/Initializer/random_uniform/max (Const)
#   context_repr/b/Initializer/random_uniform/RandomUniform (RandomUniform)
#   context_repr/b/Initializer/random_uniform/sub (Sub)
#   context_repr/b/Initializer/random_uniform/mul (Mul)
#   context_repr/b/Initializer/random_uniform (Add)
#   context_repr/b (VariableV2) /device:GPU:0
#   context_repr/b/Assign (Assign) /device:GPU:0
#   context_repr/b/read (Identity) /device:GPU:0
#   training/context_repr/b/Adam/Initializer/zeros (Const) /device:GPU:0
#   training/context_repr/b/Adam (VariableV2) /device:GPU:0
#   training/context_repr/b/Adam/Assign (Assign) /device:GPU:0
#   training/context_repr/b/Adam/read (Identity) /device:GPU:0
#   training/context_repr/b/Adam_1/Initializer/zeros (Const) /device:GPU:0
#   training/context_repr/b/Adam_1 (VariableV2) /device:GPU:0
#   training/context_repr/b/Adam_1/Assign (Assign) /device:GPU:0
#   training/context_repr/b/Adam_1/read (Identity) /device:GPU:0
#   training_1/Adam/update_context_repr/b/ApplyAdam (ApplyAdam) /device:GPU:0
#   save/Assign_5 (Assign) /device:GPU:0
#   save/Assign_47 (Assign) /device:GPU:0
#   save/Assign_48 (Assign) /device:GPU:0
#
# 2025-09-14 12:49:08.531845: W external/org_tensorflow/tensorflow/core/common_runtime/colocation_graph.cc:1218] Failed to place the graph without changing the devices of some resources. Some of the operations (that had to be colocated with resource generating operations) are not supported on the resources' devices. Current candidate devices are [
#   /job:localhost/replica:0/task:0/device:CPU:0].
# See below for details of this colocation group:
# Colocation Debug Info:
# Colocation group had the following types and supported devices:
# Root Member(assigned_device_name_index_=-1 requested_device_name_='/device:GPU:0' assigned_device_name_='' resource_device_name_='/device:GPU:0' supported_device_types_=[CPU] possible_devices_=[]
# ApplyAdam: CPU
# Switch: CPU
# Assign: CPU
# VariableV2: CPU
# Identity: CPU
# Add: CPU
# Mul: CPU
# Sub: CPU
# RandomUniform: CPU
# Const: CPU
#
# Colocation members, user-requested devices, and framework assigned devices, if any:
#   inference/transition_params/Initializer/random_uniform/shape (Const)
#   inference/transition_params/Initializer/random_uniform/min (Const)
#   inference/transition_params/Initializer/random_uniform/max (Const)
#   inference/transition_params/Initializer/random_uniform/RandomUniform (RandomUniform)
#   inference/transition_params/Initializer/random_uniform/sub (Sub)
#   inference/transition_params/Initializer/random_uniform/mul (Mul)
#   inference/transition_params/Initializer/random_uniform (Add)
#   inference/transition_params (VariableV2) /device:GPU:0
#   inference/transition_params/Assign (Assign) /device:GPU:0
#   inference/transition_params/read (Identity) /device:GPU:0
#   inference/cond/Reshape_4/Switch (Switch) /device:GPU:0
#   inference/cond_1/ExpandDims/Switch (Switch) /device:GPU:0
#   inference/cond_2/ExpandDims_1/Switch (Switch) /device:GPU:0
#   training/inference/transition_params/Adam/Initializer/zeros (Const) /device:GPU:0
#   training/inference/transition_params/Adam (VariableV2) /device:GPU:0
#   training/inference/transition_params/Adam/Assign (Assign) /device:GPU:0
#   training/inference/transition_params/Adam/read (Identity) /device:GPU:0
#   training/inference/transition_params/Adam_1/Initializer/zeros (Const) /device:GPU:0
#   training/inference/transition_params/Adam_1 (VariableV2) /device:GPU:0
#   training/inference/transition_params/Adam_1/Assign (Assign) /device:GPU:0
#   training/inference/transition_params/Adam_1/read (Identity) /device:GPU:0
#   training_1/Adam/update_inference/transition_params/ApplyAdam (ApplyAdam) /device:GPU:0
#   save/Assign_36 (Assign) /device:GPU:0
#   save/Assign_109 (Assign) /device:GPU:0
#   save/Assign_110 (Assign) /device:GPU:0
# 12:49:09.185 [Thread-4] INFO  org.apache.spark.storage.memory.MemoryStore - Block broadcast_32 stored as values in memory (estimated size 67.2 MiB, free 9.4 GiB)
# 12:49:09.218 [Thread-4] INFO  org.apache.spark.storage.memory.MemoryStore - Block broadcast_32_piece0 stored as bytes in memory (estimated size 4.0 MiB, free 9.4 GiB)
# 12:49:09.220 [dispatcher-BlockManagerMaster] INFO  org.apache.spark.storage.BlockManagerInfo - Added broadcast_32_piece0 in memory on spark-master:7082 (size: 4.0 MiB, free: 9.4 GiB)
# 12:49:09.223 [Thread-4] INFO  org.apache.spark.storage.memory.MemoryStore - Block broadcast_32_piece1 stored as bytes in memory (estimated size 4.0 MiB, free 9.4 GiB)
# 12:49:09.223 [dispatcher-BlockManagerMaster] INFO  org.apache.spark.storage.BlockManagerInfo - Added broadcast_32_piece1 in memory on spark-master:7082 (size: 4.0 MiB, free: 9.4 GiB)
# 12:49:09.226 [Thread-4] INFO  org.apache.spark.storage.memory.MemoryStore - Block broadcast_32_piece2 stored as bytes in memory (estimated size 4.0 MiB, free 9.3 GiB)
# 12:49:09.227 [dispatcher-BlockManagerMaster] INFO  org.apache.spark.storage.BlockManagerInfo - Added broadcast_32_piece2 in memory on spark-master:7082 (size: 4.0 MiB, free: 9.4 GiB)
# 12:49:09.229 [Thread-4] INFO  org.apache.spark.storage.memory.MemoryStore - Block broadcast_32_piece3 stored as bytes in memory (estimated size 2.8 MiB, free 9.3 GiB)
# 12:49:09.232 [dispatcher-BlockManagerMaster] INFO  org.apache.spark.storage.BlockManagerInfo - Added broadcast_32_piece3 in memory on spark-master:7082 (size: 2.8 MiB, free: 9.4 GiB)
# 12:49:09.238 [Thread-4] INFO  org.apache.spark.SparkContext - Created broadcast 32 from broadcast at NerDLModel.scala:247
# [ — ]12:49:09.251 [Thread-4] INFO  org.apache.spark.storage.memory.MemoryStore - Block broadcast_33 stored as values in memory (estimated size 225.4 KiB, free 9.3 GiB)
# 12:49:09.277 [Thread-4] INFO  org.apache.spark.storage.memory.MemoryStore - Block broadcast_33_piece0 stored as bytes in memory (estimated size 44.6 KiB, free 9.3 GiB)
# 12:49:09.277 [dispatcher-BlockManagerMaster] INFO  org.apache.spark.storage.BlockManagerInfo - Added broadcast_33_piece0 in memory on spark-master:7082 (size: 44.6 KiB, free: 9.4 GiB)
# 12:49:09.278 [Thread-4] INFO  org.apache.spark.SparkContext - Created broadcast 33 from textFile at ReadWrite.scala:587
# 12:49:09.342 [Thread-4] INFO  org.apache.hadoop.mapred.FileInputFormat - Total input files to process : 1
# 12:49:09.360 [Thread-4] INFO  org.apache.spark.SparkContext - Starting job: first at ReadWrite.scala:587
# 12:49:09.365 [dag-scheduler-event-loop] INFO  org.apache.spark.scheduler.DAGScheduler - Got job 17 (first at ReadWrite.scala:587) with 1 output partitions
# 12:49:09.365 [dag-scheduler-event-loop] INFO  org.apache.spark.scheduler.DAGScheduler - Final stage: ResultStage 17 (first at ReadWrite.scala:587)
# 12:49:09.365 [dag-scheduler-event-loop] INFO  org.apache.spark.scheduler.DAGScheduler - Parents of final stage: List()
# 12:49:09.365 [dag-scheduler-event-loop] INFO  org.apache.spark.scheduler.DAGScheduler - Missing parents: List()
# 12:49:09.367 [dag-scheduler-event-loop] INFO  org.apache.spark.scheduler.DAGScheduler - Submitting ResultStage 17 (file:/root/cache_pretrained/recognize_entities_dl_en_4.4.2_3.4_1685041151703/stages/5_NER_CONVERTER_389b80afbf7d/metadata MapPartitionsRDD[27] at textFile at ReadWrite.scala:587), which has no missing parents
# 12:49:09.370 [dag-scheduler-event-loop] INFO  org.apache.spark.storage.memory.MemoryStore - Block broadcast_34 stored as values in memory (estimated size 5.1 KiB, free 9.3 GiB)
# 12:49:09.375 [dag-scheduler-event-loop] INFO  org.apache.spark.storage.memory.MemoryStore - Block broadcast_34_piece0 stored as bytes in memory (estimated size 3.0 KiB, free 9.3 GiB)
# 12:49:09.377 [dispatcher-BlockManagerMaster] INFO  org.apache.spark.storage.BlockManagerInfo - Added broadcast_34_piece0 in memory on spark-master:7082 (size: 3.0 KiB, free: 9.4 GiB)
# 12:49:09.379 [dag-scheduler-event-loop] INFO  org.apache.spark.SparkContext - Created broadcast 34 from broadcast at DAGScheduler.scala:1585
# 12:49:09.382 [dag-scheduler-event-loop] INFO  org.apache.spark.scheduler.DAGScheduler - Submitting 1 missing tasks from ResultStage 17 (file:/root/cache_pretrained/recognize_entities_dl_en_4.4.2_3.4_1685041151703/stages/5_NER_CONVERTER_389b80afbf7d/metadata MapPartitionsRDD[27] at textFile at ReadWrite.scala:587) (first 15 tasks are for partitions Vector(0))
# 12:49:09.383 [dag-scheduler-event-loop] INFO  org.apache.spark.scheduler.TaskSchedulerImpl - Adding task set 17.0 with 1 tasks resource profile 0
# 12:49:09.384 [dag-scheduler-event-loop] INFO  org.apache.spark.scheduler.FairSchedulableBuilder - Added task set TaskSet_17.0 tasks to pool default
# 12:49:09.387 [dispatcher-event-loop-1] INFO  org.apache.spark.scheduler.TaskSetManager - Starting task 0.0 in stage 17.0 (TID 27) (0ea22e89e591, executor driver, partition 0, PROCESS_LOCAL, 37301 bytes)
# 12:49:09.388 [Executor task launch worker for task 0.0 in stage 17.0 (TID 27)] INFO  org.apache.spark.executor.Executor - Running task 0.0 in stage 17.0 (TID 27)
# 12:49:09.396 [Executor task launch worker for task 0.0 in stage 17.0 (TID 27)] INFO  org.apache.spark.rdd.HadoopRDD - Input split: file:/root/cache_pretrained/recognize_entities_dl_en_4.4.2_3.4_1685041151703/stages/5_NER_CONVERTER_389b80afbf7d/metadata/part-00000:0+309
# 12:49:09.405 [Executor task launch worker for task 0.0 in stage 17.0 (TID 27)] INFO  org.apache.spark.executor.Executor - Finished task 0.0 in stage 17.0 (TID 27). 1251 bytes result sent to driver
# 12:49:09.407 [task-result-getter-0] INFO  org.apache.spark.scheduler.TaskSetManager - Finished task 0.0 in stage 17.0 (TID 27) in 21 ms on 0ea22e89e591 (executor driver) (1/1)
# 12:49:09.407 [task-result-getter-0] INFO  org.apache.spark.scheduler.TaskSchedulerImpl - Removed TaskSet 17.0, whose tasks have all completed, from pool default
# 12:49:09.407 [dag-scheduler-event-loop] INFO  org.apache.spark.scheduler.DAGScheduler - ResultStage 17 (first at ReadWrite.scala:587) finished in 0.039 s
# 12:49:09.408 [dag-scheduler-event-loop] INFO  org.apache.spark.scheduler.DAGScheduler - Job 17 is finished. Cancelling potential speculative or zombie tasks for this job
# 12:49:09.408 [dag-scheduler-event-loop] INFO  org.apache.spark.scheduler.TaskSchedulerImpl - Killing all running tasks in stage 17: Stage finished
# 12:49:09.408 [Thread-4] INFO  org.apache.spark.scheduler.DAGScheduler - Job 17 finished: first at ReadWrite.scala:587, took 0.047460 s
# 12:49:09.419 [Thread-4] INFO  org.apache.spark.storage.memory.MemoryStore - Block broadcast_35 stored as values in memory (estimated size 225.4 KiB, free 9.3 GiB)
# 12:49:09.434 [Thread-4] INFO  org.apache.spark.storage.memory.MemoryStore - Block broadcast_35_piece0 stored as bytes in memory (estimated size 44.6 KiB, free 9.3 GiB)
# 12:49:09.434 [dispatcher-BlockManagerMaster] INFO  org.apache.spark.storage.BlockManagerInfo - Added broadcast_35_piece0 in memory on spark-master:7082 (size: 44.6 KiB, free: 9.4 GiB)
# 12:49:09.436 [Thread-4] INFO  org.apache.spark.SparkContext - Created broadcast 35 from textFile at ReadWrite.scala:587
# 12:49:09.486 [Thread-4] INFO  org.apache.hadoop.mapred.FileInputFormat - Total input files to process : 1
# 12:49:09.505 [Thread-4] INFO  org.apache.spark.SparkContext - Starting job: first at ReadWrite.scala:587
# 12:49:09.506 [dag-scheduler-event-loop] INFO  org.apache.spark.scheduler.DAGScheduler - Got job 18 (first at ReadWrite.scala:587) with 1 output partitions
# 12:49:09.506 [dag-scheduler-event-loop] INFO  org.apache.spark.scheduler.DAGScheduler - Final stage: ResultStage 18 (first at ReadWrite.scala:587)
# 12:49:09.506 [dag-scheduler-event-loop] INFO  org.apache.spark.scheduler.DAGScheduler - Parents of final stage: List()
# 12:49:09.506 [dag-scheduler-event-loop] INFO  org.apache.spark.scheduler.DAGScheduler - Missing parents: List()
# 12:49:09.506 [dag-scheduler-event-loop] INFO  org.apache.spark.scheduler.DAGScheduler - Submitting ResultStage 18 (file:/root/cache_pretrained/recognize_entities_dl_en_4.4.2_3.4_1685041151703/stages/5_NER_CONVERTER_389b80afbf7d/metadata MapPartitionsRDD[29] at textFile at ReadWrite.scala:587), which has no missing parents
# 12:49:09.508 [dag-scheduler-event-loop] INFO  org.apache.spark.storage.memory.MemoryStore - Block broadcast_36 stored as values in memory (estimated size 5.1 KiB, free 9.3 GiB)
# 12:49:09.510 [dag-scheduler-event-loop] INFO  org.apache.spark.storage.memory.MemoryStore - Block broadcast_36_piece0 stored as bytes in memory (estimated size 3.0 KiB, free 9.3 GiB)
# 12:49:09.510 [dispatcher-BlockManagerMaster] INFO  org.apache.spark.storage.BlockManagerInfo - Added broadcast_36_piece0 in memory on spark-master:7082 (size: 3.0 KiB, free: 9.4 GiB)
# 12:49:09.511 [dag-scheduler-event-loop] INFO  org.apache.spark.SparkContext - Created broadcast 36 from broadcast at DAGScheduler.scala:1585
# 12:49:09.512 [dag-scheduler-event-loop] INFO  org.apache.spark.scheduler.DAGScheduler - Submitting 1 missing tasks from ResultStage 18 (file:/root/cache_pretrained/recognize_entities_dl_en_4.4.2_3.4_1685041151703/stages/5_NER_CONVERTER_389b80afbf7d/metadata MapPartitionsRDD[29] at textFile at ReadWrite.scala:587) (first 15 tasks are for partitions Vector(0))
# 12:49:09.512 [dag-scheduler-event-loop] INFO  org.apache.spark.scheduler.TaskSchedulerImpl - Adding task set 18.0 with 1 tasks resource profile 0
# 12:49:09.513 [dag-scheduler-event-loop] INFO  org.apache.spark.scheduler.FairSchedulableBuilder - Added task set TaskSet_18.0 tasks to pool default
# 12:49:09.514 [dispatcher-event-loop-0] INFO  org.apache.spark.scheduler.TaskSetManager - Starting task 0.0 in stage 18.0 (TID 28) (0ea22e89e591, executor driver, partition 0, PROCESS_LOCAL, 37301 bytes)
# 12:49:09.515 [Executor task launch worker for task 0.0 in stage 18.0 (TID 28)] INFO  org.apache.spark.executor.Executor - Running task 0.0 in stage 18.0 (TID 28)
# 12:49:09.521 [Executor task launch worker for task 0.0 in stage 18.0 (TID 28)] INFO  org.apache.spark.rdd.HadoopRDD - Input split: file:/root/cache_pretrained/recognize_entities_dl_en_4.4.2_3.4_1685041151703/stages/5_NER_CONVERTER_389b80afbf7d/metadata/part-00000:0+309
# 12:49:09.524 [Executor task launch worker for task 0.0 in stage 18.0 (TID 28)] INFO  org.apache.spark.executor.Executor - Finished task 0.0 in stage 18.0 (TID 28). 1208 bytes result sent to driver
# 12:49:09.524 [task-result-getter-1] INFO  org.apache.spark.scheduler.TaskSetManager - Finished task 0.0 in stage 18.0 (TID 28) in 11 ms on 0ea22e89e591 (executor driver) (1/1)
# 12:49:09.524 [task-result-getter-1] INFO  org.apache.spark.scheduler.TaskSchedulerImpl - Removed TaskSet 18.0, whose tasks have all completed, from pool default
# 12:49:09.525 [dag-scheduler-event-loop] INFO  org.apache.spark.scheduler.DAGScheduler - ResultStage 18 (first at ReadWrite.scala:587) finished in 0.018 s
# 12:49:09.525 [dag-scheduler-event-loop] INFO  org.apache.spark.scheduler.DAGScheduler - Job 18 is finished. Cancelling potential speculative or zombie tasks for this job
# 12:49:09.525 [dag-scheduler-event-loop] INFO  org.apache.spark.scheduler.TaskSchedulerImpl - Killing all running tasks in stage 18: Stage finished
# 12:49:09.525 [Thread-4] INFO  org.apache.spark.scheduler.DAGScheduler - Job 18 finished: first at ReadWrite.scala:587, took 0.020023 s
# 12:49:09.533 [Thread-4] INFO  org.apache.spark.ml.util.Instrumentation - [8bcdaa19] training finished
# 12:49:09.536 [Thread-4] INFO  org.apache.spark.ml.util.Instrumentation - [3204b4b9] training finished
# [OK!]

# %%
result = pipeline.annotate('The Mona Lisa is a 16th century oil painting created by Leonardo')

# %%
result
# Out:
# {'entities': ['Mona Lisa', 'Leonardo'],
#  'document': ['The Mona Lisa is a 16th century oil painting created by Leonardo'],
#  'token': ['The',
#   'Mona',
#   'Lisa',
#   'is',
#   'a',
#   '16th',
#   'century',
#   'oil',
#   'painting',
#   'created',
#   'by',
#   'Leonardo'],
#  'ner': ['O',
#   'B-PER',
#   'I-PER',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-PER'],
#  'embeddings': ['The',
#   'Mona',
#   'Lisa',
#   'is',
#   'a',
#   '16th',
#   'century',
#   'oil',
#   'painting',
#   'created',
#   'by',
#   'Leonardo'],
#  'sentence': ['The Mona Lisa is a 16th century oil painting created by Leonardo']}
